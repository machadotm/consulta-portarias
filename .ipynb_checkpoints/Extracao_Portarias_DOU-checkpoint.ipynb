# %% [markdown]
# # Extração de Portarias Autorizativas de Pesquisas Arqueológicas no DOU
#
# Este programa automatiza a extração de informações de portarias publicadas pelo IPHAN no Diário Oficial da União. Ele coleta dados como:
#
# - **Números de processos e portarias**
# - **Empreendedores e empreendimentos**
# - **Arqueólogos responsáveis** (coordenadores e de campo)
# - **Áreas de abrangência** (municípios e estados)
# - **Prazos de validade e datas de expiração**
# - **Projetos e apoio institucional**
#
# ## Como funciona:
#
# 1. **Entrada**: Recebe uma lista de URLs das portarias no DOU
# 2. **Processamento**: Acessa cada documento, identifica e extrai as informações relevantes
# 3. **Saída**: Gera uma tabela organizada com todos os dados coletados
#
# ## Benefícios:
#
# - ⏱️ **Economia de tempo**: Processa automaticamente dezenas de documentos
# - 📊 **Dados estruturados**: Transforma texto não estruturado em tabelas organizadas
# - 🔍 **Consistência**: Padroniza formatos e calcula datas automaticamente
# - 📈 **Acumulação**: Mantém um histórico crescente das portarias processadas
#
# *Execute as células abaixo para utilizar o coletor.*

# %%
# Carregando bibliotecas

import requests
from bs4 import BeautifulSoup
import re
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta
import itertools
from typing import List, Dict, Any, Optional, Tuple

# %%
# Configuração para exibir mais linhas no pandas
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 50)

# Contador global para controlar a exibição de debug
debug_counter = {'parse_item_fields': 0, 'split_area': 0}

def scrape_portarias(links: List[str], projeto_col: str = "Projeto", 
                    accumulate_var: str = "df_portarias_acumulado") -> pd.DataFrame:
    """
    Função principal para scraping de portarias do IPHAN
    """
    
    # ----------------------- FUNÇÕES AUXILIARES -----------------------
    
    def clean_text(text: str) -> str:
        """Normaliza texto removendo espaços excessivos"""
        if pd.isna(text):
            return ""
        text = re.sub(r'\s+', ' ', str(text))
        return text.strip()
    
    def padronizar_processo(proc_str: str) -> str:
        """Padroniza processo no formato xxxxx.xxxxxx/xxxx-xx"""
        if pd.isna(proc_str):
            print("  Processo: NA (nada para padronizar)")
            return np.nan
        
        print(f"  Processo original para padronização: {proc_str}")
        
        # Remove todos os caracteres não numéricos exceto pontos, barras e hífens
        proc_clean = re.sub(r'[^0-9./-]', '', str(proc_str))
        print(f"  Processo limpo: {proc_clean}")
        
        # Verifica se já está no formato correto
        padrao_correto = r'^[0-9]{5}\.[0-9]{6}/[0-9]{4}-[0-9]{2}$'
        if re.match(padrao_correto, proc_clean):
            print("  Processo já está no formato correto")
            return proc_clean
        
        # Tenta extrair e reorganizar os números no formato correto
        numeros = re.findall(r'[0-9]+', proc_clean)
        print(f"  Números extraídos: {', '.join(numeros)}")
        
        if len(numeros) >= 4:
            # Formato: xxxxx.xxxxxx/xxxx-xx
            parte1 = str(numeros[0]).zfill(5)
            parte2 = str(numeros[1]).zfill(6)
            parte3 = str(numeros[2]).zfill(4)
            parte4 = str(numeros[3]).zfill(2)
            
            processo_padronizado = f"{parte1}.{parte2}/{parte3}-{parte4}"
            print(f"  Processo padronizado: {processo_padronizado}")
            
            # Verifica se o resultado está no formato correto
            if re.match(padrao_correto, processo_padronizado):
                print("  Processo padronizado com SUCESSO")
                return processo_padronizado
        
        # Se não conseguiu padronizar, retorna o original limpo
        print("  Processo NÃO padronizado, retornando original limpo")
        return proc_clean
    
    def extrair_processo(lines: List[str]) -> str:
        """Extrai processo dos parágrafos específicos"""
        processo = np.nan
        
        print("  Buscando processo nos parágrafos específicos...")
        
        # Padrões para buscar o processo
        padroes = [
            # Parágrafo iniciado por "Processo nº" ou "Processo n.º"
            r"^Processo\s+n[º°\.]?\s*[:\\s]*([^\n]+)",
            r"^PROCESSO\s+N[º°\.]?\s*[:\\s]*([^\n]+)",
            
            # Parágrafo iniciado por número de dois dígitos seguido de "-Processo nº"  
            r"^\d{2}-\s*Processo\s+n[º°\.]?\s*[:\\s]*([^\n]+)",
            r"^\d{2}-\s*PROCESSO\s+N[º°\.]?\s*[:\\s]*([^\n]+)"
        ]
        
        # Procura nos padrões
        for i, padrao in enumerate(padroes, 1):
            print(f"  Tentando padrão {i}: {padrao}")
            
            linha_processo = [line for line in lines if re.search(padrao, line, re.IGNORECASE)]
            if linha_processo:
                print(f"  Linha encontrada com padrão {i}: {linha_processo[0]}")
                
                # Extrai o texto após "nº" ou "n.º"
                match = re.search(padrao, linha_processo[0], re.IGNORECASE)
                if match and match.group(1):
                    texto_processo = clean_text(match.group(1))
                    print(f"  Texto do processo extraído: {texto_processo}")
                    
                    # Remove possíveis descrições após o número
                    texto_processo = re.split(r'\s+-\s+|\s+–\s+|\s*[,;]\s*', texto_processo)[0]
                    print(f"  Texto do processo limpo: {texto_processo}")
                    
                    processo = texto_processo
                    break
        
        # Se encontrou algum texto de processo, tenta padronizar
        if not pd.isna(processo) and processo != "":
            print("  Processo encontrado, iniciando padronização...")
            processo = padronizar_processo(processo)
        else:
            print("  Nenhum processo encontrado nos parágrafos específicos")
        
        return processo
    
    def extract_dou_date(header_lines: List[str]) -> str:
        """Extrai data dd/mm/aaaa de 'Publicado em: ... |'"""
        print("=== EXTRAINDO DATA DOU ===")
        
        # Procura em todas as linhas do header por padrões de data
        for line in header_lines:
            print(f"  Analisando linha: {line}")
            
            # Padrão 1: "Publicado em: DD/MM/AAAA"
            match = re.search(r'Publicado em:\s*([0-9]{2}/[0-9]{2}/[0-9]{4})', line, re.IGNORECASE)
            if match:
                date_str = match.group(1)
                print(f"  Data encontrada (padrão 1): {date_str}")
                return date_str
            
            # Padrão 2: "Publicado em DD/MM/AAAA"
            match = re.search(r'Publicado em\s+([0-9]{2}/[0-9]{2}/[0-9]{4})', line, re.IGNORECASE)
            if match:
                date_str = match.group(1)
                print(f"  Data encontrada (padrão 2): {date_str}")
                return date_str
            
            # Padrão 3: Data no formato DD/MM/AAAA em qualquer lugar
            match = re.search(r'([0-9]{2}/[0-9]{2}/[0-9]{4})', line)
            if match:
                date_str = match.group(1)
                # Verifica se é uma data válida (evita capturar números de processo)
                try:
                    datetime.strptime(date_str, '%d/%m/%Y')
                    # Verifica se não está em contexto de processo
                    if not re.search(r'processo|proc\.|nº', line, re.IGNORECASE):
                        print(f"  Data encontrada (padrão 3): {date_str}")
                        return date_str
                except ValueError:
                    continue
        
        print("  Nenhuma data encontrada no header")
        return np.nan
    
    def extract_portaria(page: BeautifulSoup, all_text_lines: List[str] = None) -> str:
        """Extrai a Portaria do título da página"""
        title_text = np.nan
        try:
            title_element = page.find('title')
            title_text = clean_text(title_element.get_text()) if title_element else np.nan
        except:
            pass
        
        # CORREÇÃO: Substituir \p{P} por [^\w\s] (qualquer caractere que não seja palavra ou espaço)
        pattern_full = r'(?i)\bPortaria\b[^\d\n\r]{0,30}?(?:N[^\w\s]?\s*)?(\d{1,3})\s*,\s*de\s*\d{1,2}\s+de\s+[A-Za-zà-úÀ-Ú]+\s+de\s*(\d{4})'
        
        if not pd.isna(title_text):
            match = re.search(pattern_full, title_text)
            if match:
                num, ano = match.groups()
                return f"Portaria nº {int(num)}/{ano}"
        
        if all_text_lines:
            big_text = ' '.join(all_text_lines)
            match = re.search(pattern_full, big_text)
            if match:
                num, ano = match.groups()
                return f"Portaria nº {int(num)}/{ano}"
        
        # Padrão mais flexível - também corrigido
        pattern_loose = r'(?i)\bPortaria\b[^\d\n\r]{0,30}?(?:N[^\w\s]?\s*)?(\d{1,3}).*?(\d{4})'
        
        if not pd.isna(title_text):
            match = re.search(pattern_loose, title_text)
            if match:
                num, ano = match.groups()
                return f"Portaria nº {int(num)}/{ano}"
        
        if all_text_lines:
            big_text = ' '.join(all_text_lines)
            match = re.search(pattern_loose, big_text)
            if match:
                num, ano = match.groups()
                return f"Portaria nº {int(num)}/{ano}"
        
        return np.nan
    
    def slice_header(lines: List[str]) -> List[str]:
        """Captura cabeçalho"""
        start_idx = next((i for i, line in enumerate(lines) 
                         if re.search(r'^Diário Oficial da União', line, re.IGNORECASE)), 0)
        
        end_pattern = r'^(O\s+Diretor|A\s+Diretora|O\s+Diretora|A\s+Diretor)\b'
        end_idx = next((i for i, line in enumerate(lines) 
                       if re.search(end_pattern, line, re.IGNORECASE)), min(len(lines), start_idx + 50))
        
        return lines[start_idx:end_idx+1]
    
    def extract_annex_items(annex_lines: List[str]) -> List[List[str]]:
        """Extrai blocos de itens dentro de um ANEXO"""
        starts = [i for i, line in enumerate(annex_lines) if re.match(r'^\d{2}-', line)]
        if not starts:
            return []
        
        # Padrão expandido para detectar fim do bloco
        end_pattern = r'(meses|mês|mes|mês\.|meses\.|mês\.|mes\.|ano\.|anos\.|ano|anos)\s*\)?\s*$'
        ends = [i for i, line in enumerate(annex_lines) if re.search(end_pattern, line, re.IGNORECASE)]
        
        items = []
        for s in starts:
            e = next((end for end in ends if end >= s), min(s + 20, len(annex_lines) - 1))
            items.append(annex_lines[s:e+1])
        
        return items
    
    def parse_item_fields(item_lines: List[str]) -> pd.DataFrame:
        """Analisa campos de um item - VERSÃO ATUALIZADA COM DEBUG LIMITADO"""
        # Controle de exibição de debug - apenas para os primeiros 1 registros
        debug_counter['parse_item_fields'] += 1
        show_debug = debug_counter['parse_item_fields'] <= 1
        
        if show_debug:
            print("\n=== INICIANDO PARSE_ITEM_FIELDS ===")
        
        lines = [clean_text(line) for line in item_lines if len(clean_text(line)) > 0]
        full_text = ' '.join(lines)
        
        if show_debug:
            print(f"Número de linhas do item: {len(lines)}")
            print(f"Texto completo do item (primeiros 500 chars): {full_text[:500]}\n")
            
            # Imprime cada linha numerada (limitado a 5 linhas para não poluir)
            for i, line in enumerate(lines[:1], 1):
                print(f"Linha {i}: {line}")
            if len(lines) > 1:
                print(f"... ({len(lines) - 1} linhas omitidas)")
            print()
        
        # PROCESSO - NOVA IMPLEMENTAÇÃO
        if show_debug:
            print("=== EXTRAÇÃO DO PROCESSO ===")
        proc_val = extrair_processo(lines)
        
        # Segundo: se não encontrou, tenta o padrão completo no texto
        if pd.isna(proc_val):
            if show_debug:
                print("  Buscando padrão completo no texto...")
            proc_pattern = r'([0-9]{5}\.[0-9]{6}/[0-9]{4}-[0-9]{2})'
            match = re.search(proc_pattern, full_text)
            if match:
                proc_val = match.group(1)
                if show_debug:
                    print(f"  Processo encontrado com padrão completo: {proc_val}")
            else:
                if show_debug:
                    print("  Nenhum processo encontrado com padrão completo")
        
        # Terceiro: busca alternativa em qualquer linha que contenha "Processo"
        if pd.isna(proc_val):
            if show_debug:
                print("  Buscando alternativa em linhas com 'Processo'...")
            for ln in lines:
                if re.search(r'Processo\s+n\.?\s*º|\d{2}-\s*Processo', ln, re.IGNORECASE):
                    if show_debug:
                        print(f"  Linha com menção a processo: {ln}")
                    # Tenta o padrão completo primeiro
                    match = re.search(r'([0-9]{5}\.[0-9]{6}/[0-9]{4}-[0-9]{2})', ln)
                    if match:
                        proc_val = match.group(1)
                        if show_debug:
                            print(f"  Processo encontrado com padrão completo na linha: {proc_val}")
                        break
                    
                    # Fallback: extrai qualquer sequência numérica após "nº"
                    match = re.search(r'Processo\s+n\.?\s*º?\s*[:\\s]*([0-9\.\/\-]+)', ln, re.IGNORECASE)
                    if match and match.group(1):
                        alt = match.group(1)
                        if show_debug:
                            print(f"  Sequência numérica encontrada após 'nº': {alt}")
                        proc_val = padronizar_processo(alt)
                        if not pd.isna(proc_val):
                            if show_debug:
                                print(f"  Processo padronizado com sucesso: {proc_val}")
                            break
        
        if show_debug:
            print(f"  PROCESSO FINAL: {proc_val}\n")
        
        # N_Autorizacao
        if show_debug:
            print("=== EXTRAÇÃO DA AUTORIZAÇÃO ===")
        n_aut = np.nan
        for ln in lines:
            if re.match(r'^\d{2}-', ln):
                match = re.match(r'^(\d{2})-', ln)
                n_aut = match.group(1) if match else np.nan
                if show_debug:
                    print(f"  N_Autorizacao encontrado: {n_aut}")
                break
        
        if pd.isna(n_aut) and show_debug:
            print("  Nenhuma autorização encontrada")
        
        # CAPTURA ROBUSTA DE ARQUEÓLOGOS
        if show_debug:
            print("=== EXTRAÇÃO DE ARQUEÓLOGOS ===")
        coord_val = np.nan
        campo_val = np.nan
        matched_raw = []
        
        # Padrões para coordenadores - case insensitive para toda a string
        coord_patterns = [
            r"[Aa]rque[óo]logo [Cc]oordenador:\s*([^.\"]+)\.?",
            r"[Aa]rque[óo]loga [Cc]oordenadora:\s*([^.\"]+)\.?", 
            r"[Aa]rque[óo]logo [Cc]oordenador [Gg]eral:\s*([^.\"]+)\.?",
            r"[Aa]rque[óo]logos [Cc]oordenadores [Gg]eral:\s*([^.\"]+)\.?",
            r"[Aa]rque[óo]logos [Cc]oordenadores [Gg]erais:\s*([^.\"]+)\.?",
            r"[Aa]rque[óo]loga [Cc]oordenadora [Gg]eral:\s*([^.\"]+)\.?",
            r"[Aa]rque[óo]logas [Cc]oordenadoras [Gg]eral:\s*([^.\"]+)\.?",
            r"[Aa]rque[óo]logas [Cc]oordenadoras [Gg]erais:\s*([^.\"]+)\.?",
            r"[Aa]rque[óo]logo [Cc]oordenador e de [Cc]ampo:\s*([^.\"]+)\.?",
            r"[Aa]rque[óo]loga [Cc]oordenadora e de [Cc]ampo:\s*([^.\"]+)\.?",
            r"[Aa]rque[óo]logos [Cc]oordenadores:\s*([^.\"]+)\.?",
            r"[Aa]rque[óo]logas [Cc]oordenadoras:\s*([^.\"]+)\.?",
            r"[Aa]rque[óo]logos [Cc]oordenadores e de [Cc]ampo:\s*([^.\"]+)\.?",
            r"[Aa]rque[óo]logas [Cc]oordenadoras e de [Cc]ampo:\s*([^.\"]+)\.?",
            r"[Aa]rque[óo]logo [Cc]oordenador [Gg]eral e de [Cc]ampo:\s*([^.\"]+)\.?",
            r"[Aa]rque[óo]loga [Cc]oordenadora [Gg]eral e de [Cc]ampo:\s*([^.\"]+)\.?",
            r"[Aa]rque[óo]logos [Cc]oordenadores [Gg]eral e de [Cc]ampo:\s*([^.\"]+)\.?",
            r"[Aa]rque[óo]logas [Cc]oordenadoras [Gg]eral e de [Cc]ampo:\s*([^.\"]+)\.?"
        ]
        
        # Padrões para campo - case insensitive para toda a string
        campo_patterns = [
            r"[Aa]rque[óo]logo de [Cc]ampo:\s*([^.\"]+)\.?",
            r"[Aa]rque[óo]loga de [Cc]ampo:\s*([^.\"]+)\.?",
            r"[Aa]rque[óo]logos de [Cc]ampo:\s*([^.\"]+)\.?", 
            r"[Aa]rque[óo]logas de [Cc]ampo:\s*([^.\"]+)\.?",
            r"[Aa]rque[óo]logo [Cc]oordenador de [Cc]ampo:\s*([^.\"]+)\.?",
            r"[Aa]rque[óo]logos [Cc]oordenador de [Cc]ampo:\s*([^.\"]+)\.?",
            r"[Aa]rque[óo]loga [Cc]oordenadora de [Cc]ampo:\s*([^.\"]+)\.?",
            r"[Aa]rque[óo]logos [Cc]oordenadores de [Cc]ampo:\s*([^.\"]+)\.?",
            r"[Aa]rque[óo]logas [Cc]oordenadoras de [Cc]ampo:\s*([^.\"]+)\.?",
            r"[Aa]rque[óo]logo [Cc]oordenador e de [Cc]ampo:\s*([^.\"]+)\.?",
            r"[Aa]rque[óo]loga [Cc]oordenadora e de [Cc]ampo:\s*([^.\"]+)\.?",
            r"[Aa]rque[óo]logos [Cc]oordenadores e de [Cc]ampo:\s*([^.\"]+)\.?",
            r"[Aa]rque[óo]logas [Cc]oordenadoras e de [Cc]ampo:\s*([^.\"]+)\.?",
            r"[Aa]rque[óo]loga [Cc]oordena[çc][ãa]o de [Cc]ampo:\s*([^.\"]+)\.?",
            r"[Aa]rque[óo]loga [Cc]oordena[çc][ãa]o de campo:\s*([^.\"]+)\.?",
            r"[Aa]rque[óo]logo [Cc]oordena[çc][ãa]o de [Cc]ampo:\s*([^.\"]+)\.?",
            r"[Cc]oordena[çc][ãa]o de [Cc]ampo:\s*([^.\"]+)\.?",
            r"[Aa]rque[óo]logo [Cc]oordena[çc][ãa]o de campo:\s*([^.\"]+)\.?",
            r"[Aa]rque[óo]logo [Cc]oordenador [Gg]eral e de [Cc]ampo:\s*([^.\"]+)\.?",
            r"[Aa]rque[óo]loga [Cc]oordenadora [Gg]eral e de [Cc]ampo:\s*([^.\"]+)\.?",
            r"[Aa]rque[óo]logos [Cc]oordenadores [Gg]eral e de [Cc]ampo:\s*([^.\"]+)\.?",
            r"[Aa]rque[óo]logas [Cc]oordenadoras [Gg]eral e de [Cc]ampo:\s*([^.\"]+)\.?"
        ]
        
        # Procura por arqueólogos nas linhas
        for ln in lines:
            # Verifica coordenadores
            for pattern in coord_patterns:
                match = re.search(pattern, ln)
                if match:
                    value = clean_text(match.group(1))
                    if value and value != "":
                        coord_val = value if pd.isna(coord_val) else f"{coord_val}; {value}"
                        matched_raw.append(ln)
                        if show_debug:
                            print(f"  Arqueólogo Coordenador encontrado: {value}")
                        break
            
            # Verifica campo
            for pattern in campo_patterns:
                match = re.search(pattern, ln)
                if match:
                    value = clean_text(match.group(1))
                    if value and value != "":
                        campo_val = value if pd.isna(campo_val) else f"{campo_val}; {value}"
                        matched_raw.append(ln)
                        if show_debug:
                            print(f"  Arqueólogo Campo encontrado: {value}")
                        break
        
        if pd.isna(coord_val) and show_debug:
            print("  Nenhum arqueólogo coordenador encontrado")
        if pd.isna(campo_val) and show_debug:
            print("  Nenhum arqueólogo de campo encontrado")
        
        # Remove linhas capturadas
        cleaned_lines = [line for line in lines if line not in matched_raw]
        cleaned = ' '.join(cleaned_lines)
        
        if show_debug:
            print(f"  Texto após remoção de arqueólogos: {cleaned[:200]}\n")
        
        # Demais campos
        if show_debug:
            print("=== EXTRAÇÃO DOS DEMAIS CAMPOS ===")
        
        # Enquadramento_IN
        enqu_match = re.search(r'Enquadramento\s+IN:\s*([^;]+?)(?=\s+Empreendedor:|\s+Empreendimento:|\s+Projeto:|\s+Apoio\s+Institucional:|\s+Área\s+de\s+Abrangência:|\s+Prazo\s+de\s+Validade:|$)', cleaned, re.IGNORECASE)
        enqu = enqu_match.group(1) if enqu_match else np.nan
        if show_debug:
            print(f"  Enquadramento_IN: {enqu}")
        
        # Empreendedor
        empr_match = re.search(r'Empreendedor:\s*([^;]+?)(?=\s+Empreendimento:|\s+Processo|\s+Projeto:|\s+Apoio\s+Institucional:|\s+Área\s+de\s+Abrangência:|\s+Prazo\s+de\s+Validade:|$)', cleaned, re.IGNORECASE)
        empr = empr_match.group(1) if empr_match else np.nan
        if show_debug:
            print(f"  Empreendedor: {empr}")
        
        # Empreendimento
        empd_match = re.search(r'Empreendimento:\s*([^;]+?)(?=\s+Processo|\s+Projeto:|\s+Apoio\s+Institucional:|\s+Área\s+de\s+Abrangência:|\s+Prazo\s+de\s+Validade:|$)', cleaned, re.IGNORECASE)
        empd = empd_match.group(1) if empd_match else np.nan
        if show_debug:
            print(f"  Empreendimento: {empd}")
        
        # Apoio Institucional
        apoio_match = re.search(r'Apoio\s+Institucional:\s*([^;]+?)(?=\s+Área\s+de\s+Abrangência:|\s+Prazo\s+de\s+Validade:|$)', cleaned, re.IGNORECASE)
        apoio = apoio_match.group(1) if apoio_match else np.nan
        if show_debug:
            print(f"  Apoio_Institucional: {apoio}")
        
        # Extração robusta da Área de Abrangência
        area = np.nan
        area_patterns = [
            r"Área\s+de\s+Abrangência\s*:\s*(.+?)(?=\s+Prazo\s+de\s+Validade:|$)",
            r"Área\s+de\s+Abrangência\s*:\s*(.+)",
            r"Área\s+Abrangência\s*:\s*(.+)",
            r"Area\s+de\s+Abrangencia\s*:\s*(.+)"
        ]
        
        for pattern in area_patterns:
            area_match = re.search(pattern, cleaned, re.IGNORECASE | re.DOTALL)
            if area_match:
                area = area_match.group(1)
                if show_debug:
                    print(f"  Área de Abrangência encontrada com padrão: {area}")
                break
        
        # Se não encontrou, tenta buscar em todo o texto
        if pd.isna(area):
            if show_debug:
                print("  Buscando Área de Abrangência no texto completo...")
            for pattern in area_patterns:
                area_match = re.search(pattern, full_text, re.IGNORECASE | re.DOTALL)
                if area_match:
                    area = area_match.group(1)
                    if show_debug:
                        print(f"  Área de Abrangência encontrada no texto completo: {area}")
                    break
        
        if pd.isna(area) and show_debug:
            print("  Nenhuma Área de Abrangência encontrada")
        
        # Prazo de Validade - CORREÇÃO: Busca mais robusta
        if show_debug:
            print("=== EXTRAÇÃO DO PRAZO DE VALIDADE ===")
        prazo = np.nan
        prazo_patterns = [
            r"Prazo\s+de\s+Validade\s*:\s*([^;]+?)(?=\s*$|\s*\.)",
            r"Prazo\s+da\s+Validade\s*:\s*([^;]+?)(?=\s*$|\s*\.)",
            r"Prazo\s+da\s+portaria\s*:\s*([^;]+?)(?=\s*$|\s*\.)",
            r"Prazo\s+Validade\s*:\s*([^;]+?)(?=\s*$|\s*\.)",
            r"Prazo\s*:\s*([^;]+?)(?=\s*$|\s*\.)",
            r"Validade\s*:\s*([^;]+?)(?=\s*$|\s*\.)"
        ]
        
        for pattern in prazo_patterns:
            match = re.search(pattern, cleaned, re.IGNORECASE)
            if match:
                prazo = clean_text(match.group(1))
                if show_debug:
                    print(f"  Prazo de Validade encontrado com padrão '{pattern}': {prazo}")
                break
        
        # Se não encontrou, busca no texto completo
        if pd.isna(prazo):
            if show_debug:
                print("  Buscando prazo no texto completo...")
            for pattern in prazo_patterns:
                match = re.search(pattern, full_text, re.IGNORECASE)
                if match:
                    prazo = clean_text(match.group(1))
                    if show_debug:
                        print(f"  Prazo de Validade encontrado no texto completo: {prazo}")
                    break
        
        if pd.isna(prazo) and show_debug:
            print("  Nenhum Prazo de Validade encontrado")
        
        # Projeto
        proj = np.nan
        if re.search(r'Projeto:\s*', cleaned, re.IGNORECASE):
            proj_match = re.search(r'Projeto:\s*([^;]+?)(?=\s+Apoio\s+Institucional:|\s+Área\s+de\s+Abrangência:|\s+Prazo\s+de\s+Validade:|$)', cleaned, re.IGNORECASE)
            proj = proj_match.group(1) if proj_match else np.nan
            if show_debug:
                print(f"  Projeto encontrado: {proj}")
        elif show_debug:
            print("  Nenhum Projeto encontrado")
        
        if show_debug:
            print("\n=== RESUMO DOS VALORES EXTRAÍDOS ===")
            print(f"  Enquadramento_IN: {enqu}")
            print(f"  Empreendedor: {empr}")
            print(f"  Empreendimento: {empd}")
            print(f"  Projeto: {proj}")
            print(f"  Arqueologos_Coordenadores: {coord_val}")
            print(f"  Arqueologos_Campo: {campo_val}")
            print(f"  Apoio_Institucional: {apoio}")
            print(f"  Area_Abrangencia_raw: {area}")
            print(f"  Prazo_Validade: {prazo}")
        
        # Cria DataFrame com resultados
        resultado = pd.DataFrame({
            'N_Autorizacao': [n_aut],
            'Processo': [proc_val],
            'Enquadramento_IN': [enqu],
            'Empreendedor': [empr],
            'Empreendimento': [empd],
            'Projeto': [proj],
            'Arqueologos_Coordenadores': [coord_val],
            'Arqueologos_Campo': [campo_val],
            'Apoio_Institucional': [apoio],
            'Area_Abrangencia_raw': [area],
            'Prazo_Validade': [prazo]
        })
        
        if show_debug:
            print("\n=== RESUMO FINAL DO PARSE ===")
            for col in resultado.columns:
                print(f"  {col}: {resultado[col].iloc[0]}")
            print("=== FIM DO PARSE_ITEM_FIELDS ===\n")
        
        return resultado
    
    def split_area(area_str: str) -> pd.DataFrame:
        """Separa municípios e estados a partir de 'Área de Abrangência'"""
        # Controle de exibição de debug - apenas para os primeiros 1 registros
        debug_counter['split_area'] += 1
        show_debug = debug_counter['split_area'] <= 1
        
        if pd.isna(area_str):
            return pd.DataFrame({
                'Municipios_Abrangencias': [np.nan],
                'Estados_Abrangencias': [np.nan]
            })
        
        if show_debug:
            print("=== INICIANDO SPLIT_AREA ===")
            print(f"Área de abrangência original: {area_str}")
        
        s = clean_text(area_str)
        if show_debug:
            print(f"Área de abrangência processada: {s}")
        
        # Lista completa de estados brasileiros
        estados_brasileiros = [
            "Acre", "Alagoas", "Amapá", "Amazonas", "Bahia", "Ceará", 
            "Distrito Federal", "Espírito Santo", "Goiás", "Maranhão", 
            "Mato Grosso", "Mato Grosso do Sul", "Minas Gerais", "Pará", 
            "Paraíba", "Paraná", "Pernambuco", "Piauí", "Rio de Janeiro", 
            "Rio Grande do Norte", "Rio Grande do Sul", "Rondônia", 
            "Roraima", "Santa Catarina", "São Paulo", "Sergipe", "Tocantins"
        ]
        
        # Extrai o conteúdo após "Área de Abrangência:"
        area_content = np.nan
        area_patterns = [
            r"(?i)Área\s+de\s+Abrangência\s*:\s*(.+)",
            r"(?i)Área\s+Abrangência\s*:\s*(.+)",
            r"(?i)Area\s+de\s+Abrangencia\s*:\s*(.+)"
        ]
        
        for pattern in area_patterns:
            match = re.search(pattern, s, re.DOTALL)
            if match:
                area_content = match.group(1)
                if show_debug:
                    print(f"Conteúdo da área de abrangência extraído: {area_content}")
                break
        
        if pd.isna(area_content):
            area_content = s
            if show_debug:
                print("Usando texto completo como conteúdo da área")
        
        # ESTRATÉGIA COMPLETAMENTE REFORMULADA
        
        # 1. PRIMEIRO: Extrair todos os estados mantendo a ORDEM CORRETA
        estados_ordenados = []
        texto_trabalho = area_content
        
        # Padrões expandidos para capturar estados
        padroes_estado = [
            # Padrões com "no Estado"
            r"no Estado do\s+([^,;.|]+)", r"no Estado de\s+([^,;.|]+)", r"no Estado da\s+([^,;.|]+)",
            r"nos Estados do\s+([^,;.|]+)", r"nos Estados de\s+([^,;.|]+)", r"nos Estados da\s+([^,;.|]+)",
            
            # Padrões com "Estado" 
            r"Estado do\s+([^,;.|]+)", r"Estado de\s+([^,;.|]+)", r"Estado da\s+([^,;.|]+)",
            
            # Padrões com "estado"
            r"estado do\s+([^,;.|]+)", r"estado de\s+([^,;.|]+)", r"estado da\s+([^,;.|]+)",
            
            # Padrão direto para Distrito Federal
            r"Distrito Federal"
        ]
        
        # Busca iterativa por estados na ordem correta
        while len(texto_trabalho) > 0:
            estado_encontrado = np.nan
            melhor_match = ""
            melhor_posicao = float('inf')
            
            for padrao in padroes_estado:
                match = re.search(padrao, texto_trabalho, re.IGNORECASE)
                if match:
                    posicao = match.start()
                    if posicao < melhor_posicao:
                        melhor_posicao = posicao
                        melhor_match = match.group(0)
                        
                        if padrao == r"Distrito Federal":
                            estado_encontrado = "Distrito Federal"
                        else:
                            estado_capturado = clean_text(match.group(1))
                            estado_limpo = re.sub(r'^(o|a|os|as|no|Estado|estado)\s+', '', estado_capturado, flags=re.IGNORECASE)
                            estado_limpo = clean_text(estado_limpo)
                            
                            if estado_limpo in estados_brasileiros:
                                estado_encontrado = estado_limpo
            
            if not pd.isna(estado_encontrado):
                if estado_encontrado not in estados_ordenados:
                    estados_ordenados.append(estado_encontrado)
                # Remove o trecho processado para continuar buscando
                texto_trabalho = texto_trabalho[melhor_posicao + len(melhor_match):]
            else:
                break
        
        # Busca por estados mencionados diretamente (fallback)
        for estado in estados_brasileiros:
            if re.search(rf'\b{estado}\b', area_content, re.IGNORECASE) and estado not in estados_ordenados:
                estados_ordenados.append(estado)
        
        if show_debug:
            print(f"Estados encontrados (ordem): {', '.join(estados_ordenados)}")
        
        # 2. SEGUNDO: Extrair municípios com estratégia mais robusta
        
        # Primeiro limpa o texto removendo informações de prazo e outras
        texto_limpo = area_content
        # Remove padrões de prazo
        texto_limpo = re.sub(r'(?i)Prazo\s+(?:da\s+)?portaria\s*:\s*[^.]+\\.?', '', texto_limpo)
        texto_limpo = re.sub(r'(?i)Prazo\s+de\s+validade\s*:\s*[^.]+\\.?', '', texto_limpo)
        # Remove "Área de Abrangência:"
        texto_limpo = re.sub(r'(?i)Área\s+de\s+Abrangência\s*:\s*', '', texto_limpo)
        texto_limpo = clean_text(texto_limpo)
        
        # Divide em blocos lógicos (por ; ou |)
        blocos = re.split(r'[;|]', texto_limpo)
        blocos = [clean_text(bloco) for bloco in blocos if len(clean_text(bloco)) > 0]
        
        if show_debug:
            print(f"Blocos encontrados: {len(blocos)}")
        
        todos_municipios = []
        
        for bloco in blocos:
            if show_debug:
                print(f"Processando bloco: {bloco}")
            
            # CORREÇÃO PRINCIPAL: Remove apenas os padrões específicos com prefixos
            bloco_limpo = bloco
            
            # Remove apenas os padrões com prefixos específicos
            padroes_prefixo_remover = [
                # Padrões com "no Estado"
                r"(?i)no Estado do\s+[^,;.|]+", r"(?i)no Estado de\s+[^,;.|]+", r"(?i)no Estado da\s+[^,;.|]+",
                r"(?i)nos Estados do\s+[^,;.|]+", r"(?i)nos Estados de\s+[^,;.|]+", r"(?i)nos Estados da\s+[^,;.|]+",
                
                # Padrões com "Estado" 
                r"(?i)Estado do\s+[^,;.|]+", r"(?i)Estado de\s+[^,;.|]+", r"(?i)Estado da\s+[^,;.|]+",
                
                # Padrões com "estado"
                r"(?i)estado do\s+[^,;.|]+", r"(?i)estado de\s+[^,;.|]+", r"(?i)estado da\s+[^,;.|]+",
                
                # Padrões com município/municípios
                r"(?i)Município de\s+", r"(?i)Municípios de\s+", r"(?i)município de\s+", r"(?i)municípios de\s+",
                
                # Padrão Distrito Federal
                r"Distrito Federal"
            ]
            
            for padrao in padroes_prefixo_remover:
                bloco_limpo = re.sub(padrao, '', bloco_limpo)
            
            # Remove prefixos comuns no início do bloco
            bloco_limpo = re.sub(r'(?i)^municípios?\s+de\s+', '', bloco_limpo)
            bloco_limpo = re.sub(r'(?i)^município\s+', '', bloco_limpo)
            bloco_limpo = re.sub(r'(?i),\s*municípios?\s+de\s+', ', ', bloco_limpo)
            bloco_limpo = clean_text(bloco_limpo)
            
            # Remove hífens problemáticos
            bloco_limpo = re.sub(r'\s*-\s*Estado\s*', ' ', bloco_limpo)
            bloco_limpo = re.sub(r'\s*-\s*$', '', bloco_limpo)
            bloco_limpo = clean_text(bloco_limpo)
            
            if show_debug:
                print(f"  Bloco limpo: {bloco_limpo}")
            
            # Extrai municípios deste bloco
            if len(bloco_limpo) > 0:
                # Divide por vírgulas primeiro
                partes = re.split(r',', bloco_limpo)
                partes = [clean_text(parte) for parte in partes if len(clean_text(parte)) > 0]
                
                municipios_bloco = []
                
                for parte in partes:
                    # Se a parte contém " e ", divide mas preserva nomes compostos
                    if re.search(r'\s+e\s+', parte) and len(parte) > 10:
                        # Divide por " e " mas verifica se não é um nome composto
                        subpartes = re.split(r'\s+e\s+', parte)
                        subpartes = [clean_text(subparte) for subparte in subpartes if len(clean_text(subparte)) > 2]
                        
                        for subparte in subpartes:
                            # Verifica se é um município válido
                            if subparte not in ["e", "de", "da", "do", "no"] and len(subparte) > 2:
                                municipios_bloco.append(subparte)
                    else:
                        # Parte única
                        if parte not in ["e", "de", "da", "do", "no"] and len(parte) > 2:
                            municipios_bloco.append(parte)
                
                # CORREÇÃO ESPECIAL: Se o bloco não gerou municípios mas contém texto válido
                if len(municipios_bloco) == 0 and len(bloco_limpo) > 3:
                    # Verifica se é um único município
                    palavras = bloco_limpo.split()
                    if len(palavras) <= 3:
                        # Considera como município se não for estado
                        if bloco_limpo not in estados_brasileiros or (bloco_limpo in estados_brasileiros and re.search(r'(?i)município', bloco)):
                            municipios_bloco.append(bloco_limpo)
                
                if show_debug:
                    print(f"  Municípios do bloco: {', '.join(municipios_bloco)}")
                todos_municipios.extend(municipios_bloco)
        
        # 3. Limpeza final dos municípios
        todos_municipios = list(set(todos_municipios))
        # Remove strings vazias ou muito curtas
        todos_municipios = [m for m in todos_municipios if len(m) > 2]
        # Remove artefatos específicos
        todos_municipios = [m for m in todos_municipios if m not in ["e", "de", "da", "do", "no"] 
                           and not re.search(r'^\s*$', m)
                           and not re.search(r'Prazo da portaria', m, re.IGNORECASE)
                           and not re.search(r'^\(.*\)$', m)]
        
        # 4. CORREÇÃO PARA CASOS ESPECIAIS
        
        # Caso especial: quando há apenas um município com mesmo nome do estado
        if len(todos_municipios) == 0 and len(estados_ordenados) == 1:
            # Verifica se o texto menciona explicitamente "Município de [estado]"
            match_municipio = re.search(r'(?i)Município(?:\s+de)?\s+([^,.;]+)', area_content)
            if match_municipio:
                municipio_candidato = clean_text(match_municipio.group(1))
                if municipio_candidato in estados_brasileiros:
                    todos_municipios.append(municipio_candidato)
                    if show_debug:
                        print(f"Caso especial: município com nome de estado - {municipio_candidato}")
        
        # 5. Formatação final
        if len(todos_municipios) > 0:
            if len(todos_municipios) == 1:
                municipios_out = todos_municipios[0]
            else:
                # Formata com vírgulas e "e" no final
                municipios_out = ', '.join(todos_municipios[:-1]) + ' e ' + todos_municipios[-1]
        else:
            municipios_out = np.nan
        
        estados_out = ', '.join(estados_ordenados) if estados_ordenados else np.nan
        
        if show_debug:
            print(f"RESULTADO FINAL - Municípios: {municipios_out}")
            print(f"RESULTADO FINAL - Estados: {estados_out}")
            print("=== FIM DO SPLIT_AREA ===\n")
        
        return pd.DataFrame({
            'Municipios_Abrangencias': [municipios_out],
            'Estados_Abrangencias': [estados_out]
        })
    
    def compute_expiration(pub_date_str: str, prazo_str: str) -> str:
        """Calcula data de expiração - VERSÃO CORRIGIDA"""
        if pd.isna(pub_date_str) or pd.isna(prazo_str):
            return np.nan
        
        print(f"=== CALCULANDO DATA DE EXPIRAÇÃO ===")
        print(f"  Data publicação: {pub_date_str}")
        print(f"  Prazo: {prazo_str}")
        
        try:
            dt = datetime.strptime(pub_date_str, '%d/%m/%Y')
        except ValueError as e:
            print(f"  ERRO: Não foi possível converter a data '{pub_date_str}': {e}")
            return np.nan
        
        # CORREÇÃO: Padrões mais robustos para extrair quantidade e unidade
        prazo_patterns = [
            r'(\d{1,3})\s*(?:\([^)]*\))?\s*(meses|mês|mes|anos|ano)',
            r'(\d{1,3})\s*(meses|mês|mes|anos|ano)',
            r'(\d{1,3})\s*(mês|mes|ano)',
            r'(\d+)\s*(m|a)\s*',
        ]
        
        qtd = None
        unit = None
        
        for pattern in prazo_patterns:
            match = re.search(pattern, prazo_str, re.IGNORECASE)
            if match:
                qtd = int(match.group(1))
                unit = match.group(2).lower()
                print(f"  Padrão encontrado: {qtd} {unit}")
                break
        
        if qtd is None or unit is None:
            print(f"  ERRO: Não foi possível extrair quantidade/unidade do prazo: {prazo_str}")
            return np.nan
        
        # Calcula a data de expiração
        if unit in ['mês', 'mes', 'meses', 'm']:
            exp_date = dt + relativedelta(months=qtd)
        elif unit in ['ano', 'anos', 'a']:
            exp_date = dt + relativedelta(years=qtd)
        else:
            print(f"  ERRO: Unidade de tempo não reconhecida: {unit}")
            return np.nan
        
        exp_date_str = exp_date.strftime('%d/%m/%Y')
        print(f"  Data de expiração calculada: {exp_date_str}")
        
        return exp_date_str
    
    def extract_tipo_regime_by_roman(section_line: str) -> Dict[str, str]:
        """Extrai 'Tipo' e 'Regimento Normativo'"""
        tipo_match = re.search(r'Expedir\s+([^,]+),', section_line, re.IGNORECASE)
        tipo = tipo_match.group(1) if tipo_match else np.nan
        
        reg_match = re.search(r'regidos\s+pela\s+(.+?)[;,]', section_line, re.IGNORECASE)
        reg = reg_match.group(1) if reg_match else np.nan
        
        return {'Tipo': tipo, 'Regimento_Normativo': reg}
    
    # ------------------------ FUNÇÃO PRINCIPAL DE SCRAPING -----------------------
    
    def scrape_portaria_iphan(url: str) -> pd.DataFrame:
        """Função principal para scraping de uma portaria individual"""
        print("=== INICIANDO SCRAPING DA PORTARIA ===")
        print(f"URL: {url}")
        
        try:
            response = requests.get(url, timeout=30)
            response.raise_for_status()
            page = BeautifulSoup(response.content, 'html.parser')
        except Exception as e:
            print(f"Erro ao acessar URL {url}: {e}")
            return pd.DataFrame()
        
        # Extrai todo o texto da página
        all_elements = page.find_all(string=True)
        lines = [clean_text(element) for element in all_elements if clean_text(element)]
        
        # Encontra início e fim do conteúdo
        start_idx = next((i for i, line in enumerate(lines) 
                         if re.search(r'^Diário Oficial da União', line, re.IGNORECASE)), 0)
        end_idx = next((i for i, line in enumerate(lines) 
                       if re.search(r'^REPORTAR ERRO', line, re.IGNORECASE)), len(lines) - 1)
        
        content = lines[start_idx:end_idx+1]
        
        header = slice_header(content)
        dou_date = extract_dou_date(header)
        portaria_fmt = extract_portaria(page, all_text_lines=content)
        
        print(f"Data DOU: {dou_date}")
        print(f"Portaria: {portaria_fmt}")
        
        # Encontra seções romanas
        roman_sections = [line for line in content 
                         if re.search(r'^([IVXLCDM]+)\s+-\s+Expedir\s+', line, re.IGNORECASE)]
        
        # Encontra anexos
        annex_idx = [i for i, line in enumerate(content) 
                    if re.search(r'^ANEXO\s+[IVX]+\b', line, re.IGNORECASE)]
        
        annex_list = []
        for i, a_start in enumerate(annex_idx):
            a_end = annex_idx[i+1] - 1 if i < len(annex_idx) - 1 else len(content) - 1
            annex_title_line = content[a_start]
            annex_roman_match = re.search(r'ANEXO\s+([IVX]+)', annex_title_line, re.IGNORECASE)
            annex_roman = annex_roman_match.group(1) if annex_roman_match else str(i+1)
            annex_lines = content[a_start+1:a_end+1]
            annex_items = extract_annex_items(annex_lines)
            annex_list.append({'roman': annex_roman, 'items': annex_items})
        
        print(f"Número de anexos encontrados: {len(annex_list)}")
        
        # Processa itens dos anexos
        items_dfs = []
        for ax in annex_list:
            if not ax['items']:
                continue
            
            for item in ax['items']:
                fields = parse_item_fields(item)
                area_split = split_area(fields['Area_Abrangencia_raw'].iloc[0])
                fields = pd.concat([fields.drop('Area_Abrangencia_raw', axis=1), area_split], axis=1)
                fields['Anexo'] = ax['roman']
                items_dfs.append(fields)
        
        if not items_dfs:
            return pd.DataFrame()
        
        items_df = pd.concat(items_dfs, ignore_index=True)
        
        # Tipo e Regimento por ANEXO com base nas seções romanas
        tipo_reg_data = []
        for rs in roman_sections:
            # Roman numeral at start
            rn_match = re.search(r'^([IVX]+)\s+-', rs)
            if rn_match:
                rn = rn_match.group(1)
                tr = extract_tipo_regime_by_roman(rs)
                tipo_reg_data.append({
                    'Anexo': rn,
                    'Tipo': tr['Tipo'],
                    'Regimento_Normativo': tr['Regimento_Normativo']
                })
        
        tipo_reg_df = pd.DataFrame(tipo_reg_data).drop_duplicates('Anexo', keep='first')
        
        # Combina com os dados principais
        if not tipo_reg_df.empty:
            items_df = items_df.merge(tipo_reg_df, on='Anexo', how='left')
        else:
            items_df['Tipo'] = np.nan
            items_df['Regimento_Normativo'] = np.nan
        
        # Adiciona colunas adicionais - CORREÇÃO: Garantir que as datas sejam processadas
        items_df['Portaria'] = portaria_fmt
        items_df['Data_Publicacao_DOU'] = dou_date
        
        # CORREÇÃO: Calcular data de expiração para cada linha
        print("=== CALCULANDO DATAS DE EXPIRAÇÃO ===")
        data_expiracao_list = []
        for idx, row in items_df.iterrows():
            data_exp = compute_expiration(row['Data_Publicacao_DOU'], row['Prazo_Validade'])
            data_expiracao_list.append(data_exp)
            print(f"  Linha {idx}: {row['Data_Publicacao_DOU']} + {row['Prazo_Validade']} = {data_exp}")
        
        items_df['Data_Expiracao'] = data_expiracao_list
        items_df['Chave_composta'] = items_df['Portaria'] + '_' + items_df['Processo'].fillna('')
        
        # Adiciona o link da portaria
        items_df['Link_Portaria_DOU'] = url
        items_df['Retificado'] = 'Não'
        
        # Define colunas finais
        final_cols = [
            "Portaria", "Data_Publicacao_DOU", "Anexo", "N_Autorizacao", "Tipo", "Regimento_Normativo", "Processo",
            "Retificado", "Enquadramento_IN", "Empreendedor", "Empreendimento", "Projeto", "Arqueologos_Coordenadores",
            "Arqueologos_Campo", "Apoio_Institucional", "Municipios_Abrangencias", "Estados_Abrangencias",
            "Prazo_Validade", "Data_Expiracao", "Link_Portaria_DOU", "Quantidade_Retificado_DOU",
            "Ultimo_Link_Retificado_DOU", "Link_Revogado_DOU", "Chave_composta"
        ]
        
        # Adiciona colunas faltantes
        for col in final_cols:
            if col not in items_df.columns:
                items_df[col] = np.nan
        
        items_df = items_df[final_cols]
        
        print("=== FINALIZANDO SCRAPING DA PORTARIA ===")
        print(f"Total de itens extraídos: {len(items_df)}")
        
        # CORREÇÃO: Mostrar apenas os primeiros 1 registros
        print(f"Primeiros 1 registros:")
        display_cols = ['Portaria', 'Data_Publicacao_DOU', 'Anexo', 'Processo', 'Data_Expiracao']
        for col in display_cols:
            if col in items_df.columns:
                for i, value in enumerate(items_df[col].head()):
                    print(f"  {col}[{i}]: {value}")
        
        print(f"Colunas extraídas: {', '.join(items_df.columns)}\n")
        
        return items_df
    
    # ------------------------ EXECUÇÃO PRINCIPAL -----------------------
    
    # VERIFICA SE EXISTE UM DF EXISTENTE NO AMBIENTE GLOBAL (simulação)
    existing_df = None
    try:
        # Em um Jupyter Notebook, você pode usar variáveis globais
        # Esta é uma simulação - na prática você precisaria gerenciar o estado
        if accumulate_var in globals():
            existing_df = globals()[accumulate_var]
            print(f"Carregando dados existentes de: {accumulate_var}")
        else:
            print(f"Criando novo dataframe: {accumulate_var}")
    except:
        existing_df = None
    
    # Processa todos os links
    results = []
    for link in links:
        try:
            result = scrape_portaria_iphan(link)
            if not result.empty:
                results.append(result)
        except Exception as e:
            print(f"Erro ao processar {link}: {e}")
            continue
    
    if not results:
        # Se não há novos dados, retorna o dataframe existente ou vazio
        if existing_df is not None:
            return existing_df
        else:
            return pd.DataFrame(columns=[
                "Portaria", "Data_Publicacao_DOU", "Anexo", "N_Autorizacao", "Tipo", "Regimento_Normativo", 
                "Retificado", "Processo", "Enquadramento_IN", "Empreendedor", "Empreendimento", "Projeto", 
                "Arqueologos_Coordenadores", "Arqueologos_Campo", "Apoio_Institucional", "Municipios_Abrangencias", 
                "Estados_Abrangencias", "Prazo_Validade", "Data_Expiracao", "Link_Portaria_DOU", 
                "Quantidade_Retificado_DOU", "Ultimo_Link_Retificado_DOU", "Link_Revogado_DOU", "Chave_composta"
            ])
    
    result_df = pd.concat(results, ignore_index=True)
    
    # COMBINA COM DADOS EXISTENTES SE HOUVER
    if existing_df is not None:
        print("Combinando com dados existentes...")
        result_df = pd.concat([existing_df, result_df], ignore_index=True).drop_duplicates()
    
    # ATUALIZA O DF NO AMBIENTE GLOBAL (simulação)
    globals()[accumulate_var] = result_df
    print(f"Dataframe atualizado: {accumulate_var}")
    print(f"Total de registros no dataframe: {len(result_df)}")
    
    # CORREÇÃO: Mostrar apenas os primeiros 1 registros do resultado final
    print(f"\n=== PRIMEIROS 5 REGISTROS DO DATAFRAME FINAL ===")
    if len(result_df) > 0:
        display_cols = ['Portaria', 'Data_Publicacao_DOU', 'Anexo', 'Processo', 'Data_Expiracao']
        for i, row in result_df.head().iterrows():
            print(f"Registro {i}:")
            for col in display_cols:
                if col in result_df.columns:
                    print(f"  {col}: {row[col]}")
            print()
    else:
        print("Nenhum registro encontrado")
    
    return result_df

# %%
# Extração dos dados

# Lista de URLs para processar
urls = [
    "https://www.in.gov.br/web/dou/-/portaria-n-101-de-4-de-novembro-de-2025-667083163",
    "https://www.in.gov.br/web/dou/-/portaria-n-102-de-6-de-novembro-de-2025-667424058",
    "https://www.in.gov.br/web/dou/-/portaria-n-104-de-10-de-novembro-de-2025-668357065",
    "https://www.in.gov.br/web/dou/-/portaria-n-106-de-13-de-novembro-de-2025-668949297"
]

# Executa o scraping
df_resultado = scrape_portarias(urls)

# Exibe os resultados
df_resultado
# Out:
# Criando novo dataframe: df_portarias_acumulado
# === INICIANDO SCRAPING DA PORTARIA ===
# URL: https://www.in.gov.br/web/dou/-/portaria-n-101-de-4-de-novembro-de-2025-667083163
# === EXTRAINDO DATA DOU ===
#   Analisando linha: Diário Oficial da União
#   Analisando linha: Diário Oficial da União
#   Analisando linha: Leitura do Jornal
#   Analisando linha: Destaques do Diário Oficial da União
#   Analisando linha: Base de Dados de Publicações do DOU
#   Analisando linha: Verificação de autenticidade
#   Analisando linha: Acesso ao sistema de envio de matérias INCom
#   Analisando linha: Concursos e Seleções
#   Analisando linha: Tutorial do APP DOU
#   Analisando linha: Tutorial INCom
#   Analisando linha: Termo de Uso e Política de Privacidade
#   Analisando linha: Portal da Imprensa Nacional
#   Analisando linha: Caminho de Navegação
#   Analisando linha: Serviços
#   Analisando linha: Diário Oficial da União
#   Analisando linha: Portaria nº 101, de 4 de novembro de 2025
#   Analisando linha: Publicador de Conteúdos e Mídias
#   Analisando linha: Portaria nº 101, de 4 de novembro de 2025
#   Analisando linha: https://www.in.gov.br/web/dou/-/portaria-n-101-de-4-de-novembro-de-2025-667083163
#   Analisando linha: Voltar
#   Analisando linha: Compartilhe:
#   Analisando linha: Facebook
#   Analisando linha: Twitter
#   Analisando linha: Linkedin
#   Analisando linha: WhatsApp
#   Analisando linha: WhatsApp
#   Analisando linha: Instagram
#   Analisando linha: Imagem não disponível
#   Analisando linha: Compartilhar
#   Analisando linha: Ícone
#   Analisando linha: Versão certificada
#   Analisando linha: Ícone
#   Analisando linha: Diário Completo
#   Analisando linha: Ícone
#   Analisando linha: Impressão
#   Analisando linha: Brasão do Brasil
#   Analisando linha: Diário Oficial da União
#   Analisando linha: Publicado em:
#   Analisando linha: 06/11/2025
#   Data encontrada (padrão 3): 06/11/2025
# Data DOU: 06/11/2025
# Portaria: Portaria nº 101/2025
# Número de anexos encontrados: 4
#
# === INICIANDO PARSE_ITEM_FIELDS ===
# Número de linhas do item: 6
# Texto completo do item (primeiros 500 chars): 01-Processo nº 01498.000778/2013-60 Projeto: Resgate, Monitoramento Arqueológico e Educação Patrimonial do Seccionamento LT 500 KV ANGELIM II - RECIFE II, C2 para a SE SUAPE I Arqueólogo Coordenador: Renato Kipnis Apoio Institucional: Museu de Arqueologia e Ciências Naturais - Universidade Católica de Pernambuco (UNICAP) Área de Abrangência: municípios de Jaboatão dos Guararapes, Ipojuca, Escada, Cabo de Santo Agostinho e Moreno, estado de Pernambuco Prazo de Validade: 12 (doze) meses
#
# Linha 1: 01-Processo nº 01498.000778/2013-60
# ... (5 linhas omitidas)
#
# === EXTRAÇÃO DO PROCESSO ===
#   Buscando processo nos parágrafos específicos...
#   Tentando padrão 1: ^Processo\s+n[º°\.]?\s*[:\\s]*([^\n]+)
#   Tentando padrão 2: ^PROCESSO\s+N[º°\.]?\s*[:\\s]*([^\n]+)
#   Tentando padrão 3: ^\d{2}-\s*Processo\s+n[º°\.]?\s*[:\\s]*([^\n]+)
#   Linha encontrada com padrão 3: 01-Processo nº 01498.000778/2013-60
#   Texto do processo extraído: 01498.000778/2013-60
#   Texto do processo limpo: 01498.000778/2013-60
#   Processo encontrado, iniciando padronização...
#   Processo original para padronização: 01498.000778/2013-60
#   Processo limpo: 01498.000778/2013-60
#   Processo já está no formato correto
#   PROCESSO FINAL: 01498.000778/2013-60
#
# === EXTRAÇÃO DA AUTORIZAÇÃO ===
#   N_Autorizacao encontrado: 01
# === EXTRAÇÃO DE ARQUEÓLOGOS ===
#   Arqueólogo Coordenador encontrado: Renato Kipnis
#   Nenhum arqueólogo de campo encontrado
#   Texto após remoção de arqueólogos: 01-Processo nº 01498.000778/2013-60 Projeto: Resgate, Monitoramento Arqueológico e Educação Patrimonial do Seccionamento LT 500 KV ANGELIM II - RECIFE II, C2 para a SE SUAPE I Apoio Institucional: Mus
#
# === EXTRAÇÃO DOS DEMAIS CAMPOS ===
#   Enquadramento_IN: nan
#   Empreendedor: nan
#   Empreendimento: nan
#   Apoio_Institucional: Museu de Arqueologia e Ciências Naturais - Universidade Católica de Pernambuco (UNICAP)
#   Área de Abrangência encontrada com padrão: municípios de Jaboatão dos Guararapes, Ipojuca, Escada, Cabo de Santo Agostinho e Moreno, estado de Pernambuco
# === EXTRAÇÃO DO PRAZO DE VALIDADE ===
#   Prazo de Validade encontrado com padrão 'Prazo\s+de\s+Validade\s*:\s*([^;]+?)(?=\s*$|\s*\.)': 12 (doze) meses
#   Projeto encontrado: Resgate, Monitoramento Arqueológico e Educação Patrimonial do Seccionamento LT 500 KV ANGELIM II - RECIFE II, C2 para a SE SUAPE I
#
# === RESUMO DOS VALORES EXTRAÍDOS ===
#   Enquadramento_IN: nan
#   Empreendedor: nan
#   Empreendimento: nan
#   Projeto: Resgate, Monitoramento Arqueológico e Educação Patrimonial do Seccionamento LT 500 KV ANGELIM II - RECIFE II, C2 para a SE SUAPE I
#   Arqueologos_Coordenadores: Renato Kipnis
#   Arqueologos_Campo: nan
#   Apoio_Institucional: Museu de Arqueologia e Ciências Naturais - Universidade Católica de Pernambuco (UNICAP)
#   Area_Abrangencia_raw: municípios de Jaboatão dos Guararapes, Ipojuca, Escada, Cabo de Santo Agostinho e Moreno, estado de Pernambuco
#   Prazo_Validade: 12 (doze) meses
#
# === RESUMO FINAL DO PARSE ===
#   N_Autorizacao: 01
#   Processo: 01498.000778/2013-60
#   Enquadramento_IN: nan
#   Empreendedor: nan
#   Empreendimento: nan
#   Projeto: Resgate, Monitoramento Arqueológico e Educação Patrimonial do Seccionamento LT 500 KV ANGELIM II - RECIFE II, C2 para a SE SUAPE I
#   Arqueologos_Coordenadores: Renato Kipnis
#   Arqueologos_Campo: nan
#   Apoio_Institucional: Museu de Arqueologia e Ciências Naturais - Universidade Católica de Pernambuco (UNICAP)
#   Area_Abrangencia_raw: municípios de Jaboatão dos Guararapes, Ipojuca, Escada, Cabo de Santo Agostinho e Moreno, estado de Pernambuco
#   Prazo_Validade: 12 (doze) meses
# === FIM DO PARSE_ITEM_FIELDS ===
#
# === INICIANDO SPLIT_AREA ===
# Área de abrangência original: municípios de Jaboatão dos Guararapes, Ipojuca, Escada, Cabo de Santo Agostinho e Moreno, estado de Pernambuco
# Área de abrangência processada: municípios de Jaboatão dos Guararapes, Ipojuca, Escada, Cabo de Santo Agostinho e Moreno, estado de Pernambuco
# Usando texto completo como conteúdo da área
# Estados encontrados (ordem): Pernambuco
# Blocos encontrados: 1
# Processando bloco: municípios de Jaboatão dos Guararapes, Ipojuca, Escada, Cabo de Santo Agostinho e Moreno, estado de Pernambuco
#   Bloco limpo: Jaboatão dos Guararapes, Ipojuca, Escada, Cabo de Santo Agostinho e Moreno,
#   Municípios do bloco: Jaboatão dos Guararapes, Ipojuca, Escada, Cabo de Santo Agostinho, Moreno
# RESULTADO FINAL - Municípios: Jaboatão dos Guararapes, Escada, Ipojuca, Moreno e Cabo de Santo Agostinho
# RESULTADO FINAL - Estados: Pernambuco
# === FIM DO SPLIT_AREA ===
#
#   Buscando processo nos parágrafos específicos...
#   Tentando padrão 1: ^Processo\s+n[º°\.]?\s*[:\\s]*([^\n]+)
#   Tentando padrão 2: ^PROCESSO\s+N[º°\.]?\s*[:\\s]*([^\n]+)
#   Tentando padrão 3: ^\d{2}-\s*Processo\s+n[º°\.]?\s*[:\\s]*([^\n]+)
#   Linha encontrada com padrão 3: 01-Processo nº 01516.000269/2020-09
#   Texto do processo extraído: 01516.000269/2020-09
#   Texto do processo limpo: 01516.000269/2020-09
#   Processo encontrado, iniciando padronização...
#   Processo original para padronização: 01516.000269/2020-09
#   Processo limpo: 01516.000269/2020-09
#   Processo já está no formato correto
#   Buscando processo nos parágrafos específicos...
#   Tentando padrão 1: ^Processo\s+n[º°\.]?\s*[:\\s]*([^\n]+)
#   Linha encontrada com padrão 1: Processo n.º 01514.001637/2023-91
#   Texto do processo extraído: º 01514.001637/2023-91
#   Texto do processo limpo: º 01514.001637/2023-91
#   Processo encontrado, iniciando padronização...
#   Processo original para padronização: º 01514.001637/2023-91
#   Processo limpo: 01514.001637/2023-91
#   Processo já está no formato correto
#   Buscando processo nos parágrafos específicos...
#   Tentando padrão 1: ^Processo\s+n[º°\.]?\s*[:\\s]*([^\n]+)
#   Linha encontrada com padrão 1: Processo nº 01402.000303/2025-29
#   Texto do processo extraído: 01402.000303/2025-29
#   Texto do processo limpo: 01402.000303/2025-29
#   Processo encontrado, iniciando padronização...
#   Processo original para padronização: 01402.000303/2025-29
#   Processo limpo: 01402.000303/2025-29
#   Processo já está no formato correto
#   Buscando processo nos parágrafos específicos...
#   Tentando padrão 1: ^Processo\s+n[º°\.]?\s*[:\\s]*([^\n]+)
#   Linha encontrada com padrão 1: Processo nº: 01506.000033/2025-98
#   Texto do processo extraído: 01506.000033/2025-98
#   Texto do processo limpo: 01506.000033/2025-98
#   Processo encontrado, iniciando padronização...
#   Processo original para padronização: 01506.000033/2025-98
#   Processo limpo: 01506.000033/2025-98
#   Processo já está no formato correto
#   Buscando processo nos parágrafos específicos...
#   Tentando padrão 1: ^Processo\s+n[º°\.]?\s*[:\\s]*([^\n]+)
#   Linha encontrada com padrão 1: Processo nº: 01409.000314/2025-49
#   Texto do processo extraído: 01409.000314/2025-49
#   Texto do processo limpo: 01409.000314/2025-49
#   Processo encontrado, iniciando padronização...
#   Processo original para padronização: 01409.000314/2025-49
#   Processo limpo: 01409.000314/2025-49
#   Processo já está no formato correto
#   Buscando processo nos parágrafos específicos...
#   Tentando padrão 1: ^Processo\s+n[º°\.]?\s*[:\\s]*([^\n]+)
#   Tentando padrão 2: ^PROCESSO\s+N[º°\.]?\s*[:\\s]*([^\n]+)
#   Tentando padrão 3: ^\d{2}-\s*Processo\s+n[º°\.]?\s*[:\\s]*([^\n]+)
#   Tentando padrão 4: ^\d{2}-\s*PROCESSO\s+N[º°\.]?\s*[:\\s]*([^\n]+)
#   Nenhum processo encontrado nos parágrafos específicos
#   Buscando processo nos parágrafos específicos...
#   Tentando padrão 1: ^Processo\s+n[º°\.]?\s*[:\\s]*([^\n]+)
#   Linha encontrada com padrão 1: Processo nº: 01504.000284/2024-10
#   Texto do processo extraído: 01504.000284/2024-10
#   Texto do processo limpo: 01504.000284/2024-10
#   Processo encontrado, iniciando padronização...
#   Processo original para padronização: 01504.000284/2024-10
#   Processo limpo: 01504.000284/2024-10
#   Processo já está no formato correto
#   Buscando processo nos parágrafos específicos...
#   Tentando padrão 1: ^Processo\s+n[º°\.]?\s*[:\\s]*([^\n]+)
#   Linha encontrada com padrão 1: Processo n.º: 01506.000151/2020-91
#   Texto do processo extraído: º: 01506.000151/2020-91
#   Texto do processo limpo: º: 01506.000151/2020-91
#   Processo encontrado, iniciando padronização...
#   Processo original para padronização: º: 01506.000151/2020-91
#   Processo limpo: 01506.000151/2020-91
#   Processo já está no formato correto
#   Buscando processo nos parágrafos específicos...
#   Tentando padrão 1: ^Processo\s+n[º°\.]?\s*[:\\s]*([^\n]+)
#   Linha encontrada com padrão 1: Processo n.º: 01450.010623/2024-31
#   Texto do processo extraído: º: 01450.010623/2024-31
#   Texto do processo limpo: º: 01450.010623/2024-31
#   Processo encontrado, iniciando padronização...
#   Processo original para padronização: º: 01450.010623/2024-31
#   Processo limpo: 01450.010623/2024-31
#   Processo já está no formato correto
#   Buscando processo nos parágrafos específicos...
#   Tentando padrão 1: ^Processo\s+n[º°\.]?\s*[:\\s]*([^\n]+)
#   Linha encontrada com padrão 1: Processo n.º 01506.000401/2025-06
#   Texto do processo extraído: º 01506.000401/2025-06
#   Texto do processo limpo: º 01506.000401/2025-06
#   Processo encontrado, iniciando padronização...
#   Processo original para padronização: º 01506.000401/2025-06
#   Processo limpo: 01506.000401/2025-06
#   Processo já está no formato correto
#   Buscando processo nos parágrafos específicos...
#   Tentando padrão 1: ^Processo\s+n[º°\.]?\s*[:\\s]*([^\n]+)
#   Linha encontrada com padrão 1: Processo nº: 01504.000161/2025-51
#   Texto do processo extraído: 01504.000161/2025-51
#   Texto do processo limpo: 01504.000161/2025-51
#   Processo encontrado, iniciando padronização...
#   Processo original para padronização: 01504.000161/2025-51
#   Processo limpo: 01504.000161/2025-51
#   Processo já está no formato correto
#   Buscando processo nos parágrafos específicos...
#   Tentando padrão 1: ^Processo\s+n[º°\.]?\s*[:\\s]*([^\n]+)
#   Linha encontrada com padrão 1: Processo nº 01409.000434/2025-46
#   Texto do processo extraído: 01409.000434/2025-46
#   Texto do processo limpo: 01409.000434/2025-46
#   Processo encontrado, iniciando padronização...
#   Processo original para padronização: 01409.000434/2025-46
#   Processo limpo: 01409.000434/2025-46
#   Processo já está no formato correto
#   Buscando processo nos parágrafos específicos...
#   Tentando padrão 1: ^Processo\s+n[º°\.]?\s*[:\\s]*([^\n]+)
#   Linha encontrada com padrão 1: Processo n.º 01450.010007/2024-80
#   Texto do processo extraído: º 01450.010007/2024-80
#   Texto do processo limpo: º 01450.010007/2024-80
#   Processo encontrado, iniciando padronização...
#   Processo original para padronização: º 01450.010007/2024-80
#   Processo limpo: 01450.010007/2024-80
#   Processo já está no formato correto
#   Buscando processo nos parágrafos específicos...
#   Tentando padrão 1: ^Processo\s+n[º°\.]?\s*[:\\s]*([^\n]+)
#   Linha encontrada com padrão 1: Processo n.º 01506.000784/2025-12
#   Texto do processo extraído: º 01506.000784/2025-12
#   Texto do processo limpo: º 01506.000784/2025-12
#   Processo encontrado, iniciando padronização...
#   Processo original para padronização: º 01506.000784/2025-12
#   Processo limpo: 01506.000784/2025-12
#   Processo já está no formato correto
#   Buscando processo nos parágrafos específicos...
#   Tentando padrão 1: ^Processo\s+n[º°\.]?\s*[:\\s]*([^\n]+)
#   Linha encontrada com padrão 1: Processo nº: 01506.000633/2024-75
#   Texto do processo extraído: 01506.000633/2024-75
#   Texto do processo limpo: 01506.000633/2024-75
#   Processo encontrado, iniciando padronização...
#   Processo original para padronização: 01506.000633/2024-75
#   Processo limpo: 01506.000633/2024-75
#   Processo já está no formato correto
#   Buscando processo nos parágrafos específicos...
#   Tentando padrão 1: ^Processo\s+n[º°\.]?\s*[:\\s]*([^\n]+)
#   Linha encontrada com padrão 1: Processo nº 01410.000192/2025-51
#   Texto do processo extraído: 01410.000192/2025-51
#   Texto do processo limpo: 01410.000192/2025-51
#   Processo encontrado, iniciando padronização...
#   Processo original para padronização: 01410.000192/2025-51
#   Processo limpo: 01410.000192/2025-51
#   Processo já está no formato correto
#   Buscando processo nos parágrafos específicos...
#   Tentando padrão 1: ^Processo\s+n[º°\.]?\s*[:\\s]*([^\n]+)
#   Linha encontrada com padrão 1: Processo nº: 01508.000708/2025-89
#   Texto do processo extraído: 01508.000708/2025-89
#   Texto do processo limpo: 01508.000708/2025-89
#   Processo encontrado, iniciando padronização...
#   Processo original para padronização: 01508.000708/2025-89
#   Processo limpo: 01508.000708/2025-89
#   Processo já está no formato correto
#   Buscando processo nos parágrafos específicos...
#   Tentando padrão 1: ^Processo\s+n[º°\.]?\s*[:\\s]*([^\n]+)
#   Linha encontrada com padrão 1: Processo n.º 01450.008570/2025-79
#   Texto do processo extraído: º 01450.008570/2025-79
#   Texto do processo limpo: º 01450.008570/2025-79
#   Processo encontrado, iniciando padronização...
#   Processo original para padronização: º 01450.008570/2025-79
#   Processo limpo: 01450.008570/2025-79
#   Processo já está no formato correto
#   Buscando processo nos parágrafos específicos...
#   Tentando padrão 1: ^Processo\s+n[º°\.]?\s*[:\\s]*([^\n]+)
#   Linha encontrada com padrão 1: Processo n.º 01450.009085/2025-12
#   Texto do processo extraído: º 01450.009085/2025-12
#   Texto do processo limpo: º 01450.009085/2025-12
#   Processo encontrado, iniciando padronização...
#   Processo original para padronização: º 01450.009085/2025-12
#   Processo limpo: 01450.009085/2025-12
#   Processo já está no formato correto
#   Buscando processo nos parágrafos específicos...
#   Tentando padrão 1: ^Processo\s+n[º°\.]?\s*[:\\s]*([^\n]+)
#   Linha encontrada com padrão 1: Processo n.º 01506.900845/2017-25
#   Texto do processo extraído: º 01506.900845/2017-25
#   Texto do processo limpo: º 01506.900845/2017-25
#   Processo encontrado, iniciando padronização...
#   Processo original para padronização: º 01506.900845/2017-25
#   Processo limpo: 01506.900845/2017-25
#   Processo já está no formato correto
#   Buscando processo nos parágrafos específicos...
#   Tentando padrão 1: ^Processo\s+n[º°\.]?\s*[:\\s]*([^\n]+)
#   Linha encontrada com padrão 1: Processo n.º 01516.001103/2024-25
#   Texto do processo extraído: º 01516.001103/2024-25
#   Texto do processo limpo: º 01516.001103/2024-25
#   Processo encontrado, iniciando padronização...
#   Processo original para padronização: º 01516.001103/2024-25
#   Processo limpo: 01516.001103/2024-25
#   Processo já está no formato correto
# === CALCULANDO DATAS DE EXPIRAÇÃO ===
# === CALCULANDO DATA DE EXPIRAÇÃO ===
#   Data publicação: 06/11/2025
#   Prazo: 12 (doze) meses
#   Padrão encontrado: 12 meses
#   Data de expiração calculada: 06/11/2026
#   Linha 0: 06/11/2025 + 12 (doze) meses = 06/11/2026
# === CALCULANDO DATA DE EXPIRAÇÃO ===
#   Data publicação: 06/11/2025
#   Prazo: 24 (vinte e quatro) meses
#   Padrão encontrado: 24 meses
#   Data de expiração calculada: 06/11/2027
#   Linha 1: 06/11/2025 + 24 (vinte e quatro) meses = 06/11/2027
# === CALCULANDO DATA DE EXPIRAÇÃO ===
#   Data publicação: 06/11/2025
#   Prazo: 07 (sete) meses
#   Padrão encontrado: 7 meses
#   Data de expiração calculada: 06/06/2026
#   Linha 2: 06/11/2025 + 07 (sete) meses = 06/06/2026
# === CALCULANDO DATA DE EXPIRAÇÃO ===
#   Data publicação: 06/11/2025
#   Prazo: 03 (três) meses
#   Padrão encontrado: 3 meses
#   Data de expiração calculada: 06/02/2026
#   Linha 3: 06/11/2025 + 03 (três) meses = 06/02/2026
# === CALCULANDO DATA DE EXPIRAÇÃO ===
#   Data publicação: 06/11/2025
#   Prazo: 04 (quatro) meses
#   Padrão encontrado: 4 meses
#   Data de expiração calculada: 06/03/2026
#   Linha 4: 06/11/2025 + 04 (quatro) meses = 06/03/2026
# === CALCULANDO DATA DE EXPIRAÇÃO ===
#   Data publicação: 06/11/2025
#   Prazo: 03 (três) meses
#   Padrão encontrado: 3 meses
#   Data de expiração calculada: 06/02/2026
#   Linha 5: 06/11/2025 + 03 (três) meses = 06/02/2026
# === CALCULANDO DATA DE EXPIRAÇÃO ===
#   Data publicação: 06/11/2025
#   Prazo: 04 (quatro) meses
#   Padrão encontrado: 4 meses
#   Data de expiração calculada: 06/03/2026
#   Linha 6: 06/11/2025 + 04 (quatro) meses = 06/03/2026
# === CALCULANDO DATA DE EXPIRAÇÃO ===
#   Data publicação: 06/11/2025
#   Prazo: 03 (três) meses
#   Padrão encontrado: 3 meses
#   Data de expiração calculada: 06/02/2026
#   Linha 7: 06/11/2025 + 03 (três) meses = 06/02/2026
# === CALCULANDO DATA DE EXPIRAÇÃO ===
#   Data publicação: 06/11/2025
#   Prazo: 03 (três) meses
#   Padrão encontrado: 3 meses
#   Data de expiração calculada: 06/02/2026
#   Linha 8: 06/11/2025 + 03 (três) meses = 06/02/2026
# === CALCULANDO DATA DE EXPIRAÇÃO ===
#   Data publicação: 06/11/2025
#   Prazo: 06 (seis) meses
#   Padrão encontrado: 6 meses
#   Data de expiração calculada: 06/05/2026
#   Linha 9: 06/11/2025 + 06 (seis) meses = 06/05/2026
# === CALCULANDO DATA DE EXPIRAÇÃO ===
#   Data publicação: 06/11/2025
#   Prazo: 03 (três) meses
#   Padrão encontrado: 3 meses
#   Data de expiração calculada: 06/02/2026
#   Linha 10: 06/11/2025 + 03 (três) meses = 06/02/2026
# === CALCULANDO DATA DE EXPIRAÇÃO ===
#   Data publicação: 06/11/2025
#   Prazo: 14 (quatorze) meses
#   Padrão encontrado: 14 meses
#   Data de expiração calculada: 06/01/2027
#   Linha 11: 06/11/2025 + 14 (quatorze) meses = 06/01/2027
# === CALCULANDO DATA DE EXPIRAÇÃO ===
#   Data publicação: 06/11/2025
#   Prazo: 03 (três) meses
#   Padrão encontrado: 3 meses
#   Data de expiração calculada: 06/02/2026
#   Linha 12: 06/11/2025 + 03 (três) meses = 06/02/2026
# === CALCULANDO DATA DE EXPIRAÇÃO ===
#   Data publicação: 06/11/2025
#   Prazo: 05 (cinco) meses
#   Padrão encontrado: 5 meses
#   Data de expiração calculada: 06/04/2026
#   Linha 13: 06/11/2025 + 05 (cinco) meses = 06/04/2026
# === CALCULANDO DATA DE EXPIRAÇÃO ===
#   Data publicação: 06/11/2025
#   Prazo: 04 (quatro) meses
#   Padrão encontrado: 4 meses
#   Data de expiração calculada: 06/03/2026
#   Linha 14: 06/11/2025 + 04 (quatro) meses = 06/03/2026
# === CALCULANDO DATA DE EXPIRAÇÃO ===
#   Data publicação: 06/11/2025
#   Prazo: 02 (dois) meses
#   Padrão encontrado: 2 meses
#   Data de expiração calculada: 06/01/2026
#   Linha 15: 06/11/2025 + 02 (dois) meses = 06/01/2026
# === CALCULANDO DATA DE EXPIRAÇÃO ===
#   Data publicação: 06/11/2025
#   Prazo: 04 (quatro) meses
#   Padrão encontrado: 4 meses
#   Data de expiração calculada: 06/03/2026
#   Linha 16: 06/11/2025 + 04 (quatro) meses = 06/03/2026
# === CALCULANDO DATA DE EXPIRAÇÃO ===
#   Data publicação: 06/11/2025
#   Prazo: 04 (quatro) meses
#   Padrão encontrado: 4 meses
#   Data de expiração calculada: 06/03/2026
#   Linha 17: 06/11/2025 + 04 (quatro) meses = 06/03/2026
# === CALCULANDO DATA DE EXPIRAÇÃO ===
#   Data publicação: 06/11/2025
#   Prazo: 04 (quatro) meses
#   Padrão encontrado: 4 meses
#   Data de expiração calculada: 06/03/2026
#   Linha 18: 06/11/2025 + 04 (quatro) meses = 06/03/2026
# === CALCULANDO DATA DE EXPIRAÇÃO ===
#   Data publicação: 06/11/2025
#   Prazo: 04 (quatro) meses
#   Padrão encontrado: 4 meses
#   Data de expiração calculada: 06/03/2026
#   Linha 19: 06/11/2025 + 04 (quatro) meses = 06/03/2026
# === CALCULANDO DATA DE EXPIRAÇÃO ===
#   Data publicação: 06/11/2025
#   Prazo: 06 (seis) meses
#   Padrão encontrado: 6 meses
#   Data de expiração calculada: 06/05/2026
#   Linha 20: 06/11/2025 + 06 (seis) meses = 06/05/2026
# === CALCULANDO DATA DE EXPIRAÇÃO ===
#   Data publicação: 06/11/2025
#   Prazo: 03 (três) meses
#   Padrão encontrado: 3 meses
#   Data de expiração calculada: 06/02/2026
#   Linha 21: 06/11/2025 + 03 (três) meses = 06/02/2026
# === FINALIZANDO SCRAPING DA PORTARIA ===
# Total de itens extraídos: 22
# Primeiros 1 registros:
#   Portaria[0]: Portaria nº 101/2025
#   Portaria[1]: Portaria nº 101/2025
#   Portaria[2]: Portaria nº 101/2025
#   Portaria[3]: Portaria nº 101/2025
#   Portaria[4]: Portaria nº 101/2025
#   Data_Publicacao_DOU[0]: 06/11/2025
#   Data_Publicacao_DOU[1]: 06/11/2025
#   Data_Publicacao_DOU[2]: 06/11/2025
#   Data_Publicacao_DOU[3]: 06/11/2025
#   Data_Publicacao_DOU[4]: 06/11/2025
#   Anexo[0]: I
#   Anexo[1]: II
#   Anexo[2]: III
#   Anexo[3]: IV
#   Anexo[4]: IV
#   Processo[0]: 01498.000778/2013-60
#   Processo[1]: 01516.000269/2020-09
#   Processo[2]: 01514.001637/2023-91
#   Processo[3]: 01402.000303/2025-29
#   Processo[4]: 01506.000033/2025-98
#   Data_Expiracao[0]: 06/11/2026
#   Data_Expiracao[1]: 06/11/2027
#   Data_Expiracao[2]: 06/06/2026
#   Data_Expiracao[3]: 06/02/2026
#   Data_Expiracao[4]: 06/03/2026
# Colunas extraídas: Portaria, Data_Publicacao_DOU, Anexo, N_Autorizacao, Tipo, Regimento_Normativo, Processo, Retificado, Enquadramento_IN, Empreendedor, Empreendimento, Projeto, Arqueologos_Coordenadores, Arqueologos_Campo, Apoio_Institucional, Municipios_Abrangencias, Estados_Abrangencias, Prazo_Validade, Data_Expiracao, Link_Portaria_DOU, Quantidade_Retificado_DOU, Ultimo_Link_Retificado_DOU, Link_Revogado_DOU, Chave_composta
#
# === INICIANDO SCRAPING DA PORTARIA ===
# URL: https://www.in.gov.br/web/dou/-/portaria-n-102-de-6-de-novembro-de-2025-667424058
# === EXTRAINDO DATA DOU ===
#   Analisando linha: Diário Oficial da União
#   Analisando linha: Diário Oficial da União
#   Analisando linha: Leitura do Jornal
#   Analisando linha: Destaques do Diário Oficial da União
#   Analisando linha: Base de Dados de Publicações do DOU
#   Analisando linha: Verificação de autenticidade
#   Analisando linha: Acesso ao sistema de envio de matérias INCom
#   Analisando linha: Concursos e Seleções
#   Analisando linha: Tutorial do APP DOU
#   Analisando linha: Tutorial INCom
#   Analisando linha: Termo de Uso e Política de Privacidade
#   Analisando linha: Portal da Imprensa Nacional
#   Analisando linha: Caminho de Navegação
#   Analisando linha: Serviços
#   Analisando linha: Diário Oficial da União
#   Analisando linha: Portaria nº 102, de 6 de novembro de 2025
#   Analisando linha: Publicador de Conteúdos e Mídias
#   Analisando linha: Portaria nº 102, de 6 de novembro de 2025
#   Analisando linha: https://www.in.gov.br/web/dou/-/portaria-n-102-de-6-de-novembro-de-2025-667424058
#   Analisando linha: Voltar
#   Analisando linha: Compartilhe:
#   Analisando linha: Facebook
#   Analisando linha: Twitter
#   Analisando linha: Linkedin
#   Analisando linha: WhatsApp
#   Analisando linha: WhatsApp
#   Analisando linha: Instagram
#   Analisando linha: Imagem não disponível
#   Analisando linha: Compartilhar
#   Analisando linha: Ícone
#   Analisando linha: Versão certificada
#   Analisando linha: Ícone
#   Analisando linha: Diário Completo
#   Analisando linha: Ícone
#   Analisando linha: Impressão
#   Analisando linha: Brasão do Brasil
#   Analisando linha: Diário Oficial da União
#   Analisando linha: Publicado em:
#   Analisando linha: 07/11/2025
#   Data encontrada (padrão 3): 07/11/2025
# Data DOU: 07/11/2025
# Portaria: Portaria nº 102/2025
# Número de anexos encontrados: 4
#   Buscando processo nos parágrafos específicos...
#   Tentando padrão 1: ^Processo\s+n[º°\.]?\s*[:\\s]*([^\n]+)
#   Tentando padrão 2: ^PROCESSO\s+N[º°\.]?\s*[:\\s]*([^\n]+)
#   Tentando padrão 3: ^\d{2}-\s*Processo\s+n[º°\.]?\s*[:\\s]*([^\n]+)
#   Linha encontrada com padrão 3: 01- Processo n.º 01506.002938/2013-69
#   Texto do processo extraído: º 01506.002938/2013-69
#   Texto do processo limpo: º 01506.002938/2013-69
#   Processo encontrado, iniciando padronização...
#   Processo original para padronização: º 01506.002938/2013-69
#   Processo limpo: 01506.002938/2013-69
#   Processo já está no formato correto
#   Buscando processo nos parágrafos específicos...
#   Tentando padrão 1: ^Processo\s+n[º°\.]?\s*[:\\s]*([^\n]+)
#   Tentando padrão 2: ^PROCESSO\s+N[º°\.]?\s*[:\\s]*([^\n]+)
#   Tentando padrão 3: ^\d{2}-\s*Processo\s+n[º°\.]?\s*[:\\s]*([^\n]+)
#   Linha encontrada com padrão 3: 01- Processo n °: 01504.000034/2019-12
#   Texto do processo extraído: °: 01504.000034/2019-12
#   Texto do processo limpo: °: 01504.000034/2019-12
#   Processo encontrado, iniciando padronização...
#   Processo original para padronização: °: 01504.000034/2019-12
#   Processo limpo: 01504.000034/2019-12
#   Processo já está no formato correto
#   Buscando processo nos parágrafos específicos...
#   Tentando padrão 1: ^Processo\s+n[º°\.]?\s*[:\\s]*([^\n]+)
#   Tentando padrão 2: ^PROCESSO\s+N[º°\.]?\s*[:\\s]*([^\n]+)
#   Tentando padrão 3: ^\d{2}-\s*Processo\s+n[º°\.]?\s*[:\\s]*([^\n]+)
#   Linha encontrada com padrão 3: 02- Processo nº: 01516.000256/2025-36
#   Texto do processo extraído: 01516.000256/2025-36
#   Texto do processo limpo: 01516.000256/2025-36
#   Processo encontrado, iniciando padronização...
#   Processo original para padronização: 01516.000256/2025-36
#   Processo limpo: 01516.000256/2025-36
#   Processo já está no formato correto
#   Buscando processo nos parágrafos específicos...
#   Tentando padrão 1: ^Processo\s+n[º°\.]?\s*[:\\s]*([^\n]+)
#   Tentando padrão 2: ^PROCESSO\s+N[º°\.]?\s*[:\\s]*([^\n]+)
#   Tentando padrão 3: ^\d{2}-\s*Processo\s+n[º°\.]?\s*[:\\s]*([^\n]+)
#   Linha encontrada com padrão 3: 03- Processo nº: 01502.001705/2025-1
#   Texto do processo extraído: 01502.001705/2025-1
#   Texto do processo limpo: 01502.001705/2025-1
#   Processo encontrado, iniciando padronização...
#   Processo original para padronização: 01502.001705/2025-1
#   Processo limpo: 01502.001705/2025-1
#   Números extraídos: 01502, 001705, 2025, 1
#   Processo padronizado: 01502.001705/2025-01
#   Processo padronizado com SUCESSO
#   Buscando processo nos parágrafos específicos...
#   Tentando padrão 1: ^Processo\s+n[º°\.]?\s*[:\\s]*([^\n]+)
#   Linha encontrada com padrão 1: Processo nº 01508.000917/2024-41
#   Texto do processo extraído: 01508.000917/2024-41
#   Texto do processo limpo: 01508.000917/2024-41
#   Processo encontrado, iniciando padronização...
#   Processo original para padronização: 01508.000917/2024-41
#   Processo limpo: 01508.000917/2024-41
#   Processo já está no formato correto
#   Buscando processo nos parágrafos específicos...
#   Tentando padrão 1: ^Processo\s+n[º°\.]?\s*[:\\s]*([^\n]+)
#   Linha encontrada com padrão 1: Processo n.º 01510.000332/2025-63
#   Texto do processo extraído: º 01510.000332/2025-63
#   Texto do processo limpo: º 01510.000332/2025-63
#   Processo encontrado, iniciando padronização...
#   Processo original para padronização: º 01510.000332/2025-63
#   Processo limpo: 01510.000332/2025-63
#   Processo já está no formato correto
#   Buscando processo nos parágrafos específicos...
#   Tentando padrão 1: ^Processo\s+n[º°\.]?\s*[:\\s]*([^\n]+)
#   Linha encontrada com padrão 1: Processo nº 01514.001159/2024-08
#   Texto do processo extraído: 01514.001159/2024-08
#   Texto do processo limpo: 01514.001159/2024-08
#   Processo encontrado, iniciando padronização...
#   Processo original para padronização: 01514.001159/2024-08
#   Processo limpo: 01514.001159/2024-08
#   Processo já está no formato correto
#   Buscando processo nos parágrafos específicos...
#   Tentando padrão 1: ^Processo\s+n[º°\.]?\s*[:\\s]*([^\n]+)
#   Linha encontrada com padrão 1: Processo n.º 01551.000345/2024-75
#   Texto do processo extraído: º 01551.000345/2024-75
#   Texto do processo limpo: º 01551.000345/2024-75
#   Processo encontrado, iniciando padronização...
#   Processo original para padronização: º 01551.000345/2024-75
#   Processo limpo: 01551.000345/2024-75
#   Processo já está no formato correto
#   Buscando processo nos parágrafos específicos...
#   Tentando padrão 1: ^Processo\s+n[º°\.]?\s*[:\\s]*([^\n]+)
#   Linha encontrada com padrão 1: Processo nº 01502.001287/2025-63
#   Texto do processo extraído: 01502.001287/2025-63
#   Texto do processo limpo: 01502.001287/2025-63
#   Processo encontrado, iniciando padronização...
#   Processo original para padronização: 01502.001287/2025-63
#   Processo limpo: 01502.001287/2025-63
#   Processo já está no formato correto
#   Buscando processo nos parágrafos específicos...
#   Tentando padrão 1: ^Processo\s+n[º°\.]?\s*[:\\s]*([^\n]+)
#   Linha encontrada com padrão 1: Processo n.º: 01506.000016/2024-70
#   Texto do processo extraído: º: 01506.000016/2024-70
#   Texto do processo limpo: º: 01506.000016/2024-70
#   Processo encontrado, iniciando padronização...
#   Processo original para padronização: º: 01506.000016/2024-70
#   Processo limpo: 01506.000016/2024-70
#   Processo já está no formato correto
#   Buscando processo nos parágrafos específicos...
#   Tentando padrão 1: ^Processo\s+n[º°\.]?\s*[:\\s]*([^\n]+)
#   Linha encontrada com padrão 1: Processo n.º 01506.000160/2024-14
#   Texto do processo extraído: º 01506.000160/2024-14
#   Texto do processo limpo: º 01506.000160/2024-14
#   Processo encontrado, iniciando padronização...
#   Processo original para padronização: º 01506.000160/2024-14
#   Processo limpo: 01506.000160/2024-14
#   Processo já está no formato correto
#   Buscando processo nos parágrafos específicos...
#   Tentando padrão 1: ^Processo\s+n[º°\.]?\s*[:\\s]*([^\n]+)
#   Linha encontrada com padrão 1: Processo nº: 01508.000527/2025-52
#   Texto do processo extraído: 01508.000527/2025-52
#   Texto do processo limpo: 01508.000527/2025-52
#   Processo encontrado, iniciando padronização...
#   Processo original para padronização: 01508.000527/2025-52
#   Processo limpo: 01508.000527/2025-52
#   Processo já está no formato correto
#   Buscando processo nos parágrafos específicos...
#   Tentando padrão 1: ^Processo\s+n[º°\.]?\s*[:\\s]*([^\n]+)
#   Linha encontrada com padrão 1: Processo nº 01450.003173/2025-19
#   Texto do processo extraído: 01450.003173/2025-19
#   Texto do processo limpo: 01450.003173/2025-19
#   Processo encontrado, iniciando padronização...
#   Processo original para padronização: 01450.003173/2025-19
#   Processo limpo: 01450.003173/2025-19
#   Processo já está no formato correto
#   Buscando processo nos parágrafos específicos...
#   Tentando padrão 1: ^Processo\s+n[º°\.]?\s*[:\\s]*([^\n]+)
#   Linha encontrada com padrão 1: Processo n.º 01506.001904/2024-18
#   Texto do processo extraído: º 01506.001904/2024-18
#   Texto do processo limpo: º 01506.001904/2024-18
#   Processo encontrado, iniciando padronização...
#   Processo original para padronização: º 01506.001904/2024-18
#   Processo limpo: 01506.001904/2024-18
#   Processo já está no formato correto
#   Buscando processo nos parágrafos específicos...
#   Tentando padrão 1: ^Processo\s+n[º°\.]?\s*[:\\s]*([^\n]+)
#   Linha encontrada com padrão 1: Processo n.º: 01506.000683/2019-95
#   Texto do processo extraído: º: 01506.000683/2019-95
#   Texto do processo limpo: º: 01506.000683/2019-95
#   Processo encontrado, iniciando padronização...
#   Processo original para padronização: º: 01506.000683/2019-95
#   Processo limpo: 01506.000683/2019-95
#   Processo já está no formato correto
#   Buscando processo nos parágrafos específicos...
#   Tentando padrão 1: ^Processo\s+n[º°\.]?\s*[:\\s]*([^\n]+)
#   Tentando padrão 2: ^PROCESSO\s+N[º°\.]?\s*[:\\s]*([^\n]+)
#   Tentando padrão 3: ^\d{2}-\s*Processo\s+n[º°\.]?\s*[:\\s]*([^\n]+)
#   Tentando padrão 4: ^\d{2}-\s*PROCESSO\s+N[º°\.]?\s*[:\\s]*([^\n]+)
#   Nenhum processo encontrado nos parágrafos específicos
#   Buscando processo nos parágrafos específicos...
#   Tentando padrão 1: ^Processo\s+n[º°\.]?\s*[:\\s]*([^\n]+)
#   Linha encontrada com padrão 1: Processo n.º 01506.000537/2025-16
#   Texto do processo extraído: º 01506.000537/2025-16
#   Texto do processo limpo: º 01506.000537/2025-16
#   Processo encontrado, iniciando padronização...
#   Processo original para padronização: º 01506.000537/2025-16
#   Processo limpo: 01506.000537/2025-16
#   Processo já está no formato correto
#   Buscando processo nos parágrafos específicos...
#   Tentando padrão 1: ^Processo\s+n[º°\.]?\s*[:\\s]*([^\n]+)
#   Linha encontrada com padrão 1: Processo nº: 01506.001753/2024-90
#   Texto do processo extraído: 01506.001753/2024-90
#   Texto do processo limpo: 01506.001753/2024-90
#   Processo encontrado, iniciando padronização...
#   Processo original para padronização: 01506.001753/2024-90
#   Processo limpo: 01506.001753/2024-90
#   Processo já está no formato correto
#   Buscando processo nos parágrafos específicos...
#   Tentando padrão 1: ^Processo\s+n[º°\.]?\s*[:\\s]*([^\n]+)
#   Linha encontrada com padrão 1: Processo n.º 01506.001719/2024-15
#   Texto do processo extraído: º 01506.001719/2024-15
#   Texto do processo limpo: º 01506.001719/2024-15
#   Processo encontrado, iniciando padronização...
#   Processo original para padronização: º 01506.001719/2024-15
#   Processo limpo: 01506.001719/2024-15
#   Processo já está no formato correto
#   Buscando processo nos parágrafos específicos...
#   Tentando padrão 1: ^Processo\s+n[º°\.]?\s*[:\\s]*([^\n]+)
#   Linha encontrada com padrão 1: Processo n.º 01402.000182/2025-15
#   Texto do processo extraído: º 01402.000182/2025-15
#   Texto do processo limpo: º 01402.000182/2025-15
#   Processo encontrado, iniciando padronização...
#   Processo original para padronização: º 01402.000182/2025-15
#   Processo limpo: 01402.000182/2025-15
#   Processo já está no formato correto
#   Buscando processo nos parágrafos específicos...
#   Tentando padrão 1: ^Processo\s+n[º°\.]?\s*[:\\s]*([^\n]+)
#   Linha encontrada com padrão 1: Processo nº: 01506.000667/2025-41
#   Texto do processo extraído: 01506.000667/2025-41
#   Texto do processo limpo: 01506.000667/2025-41
#   Processo encontrado, iniciando padronização...
#   Processo original para padronização: 01506.000667/2025-41
#   Processo limpo: 01506.000667/2025-41
#   Processo já está no formato correto
#   Buscando processo nos parágrafos específicos...
#   Tentando padrão 1: ^Processo\s+n[º°\.]?\s*[:\\s]*([^\n]+)
#   Linha encontrada com padrão 1: Processo nº:01516.001097/2024-14
#   Texto do processo extraído: 01516.001097/2024-14
#   Texto do processo limpo: 01516.001097/2024-14
#   Processo encontrado, iniciando padronização...
#   Processo original para padronização: 01516.001097/2024-14
#   Processo limpo: 01516.001097/2024-14
#   Processo já está no formato correto
#   Buscando processo nos parágrafos específicos...
#   Tentando padrão 1: ^Processo\s+n[º°\.]?\s*[:\\s]*([^\n]+)
#   Linha encontrada com padrão 1: Processo nº 01422.000248/2025-39
#   Texto do processo extraído: 01422.000248/2025-39
#   Texto do processo limpo: 01422.000248/2025-39
#   Processo encontrado, iniciando padronização...
#   Processo original para padronização: 01422.000248/2025-39
#   Processo limpo: 01422.000248/2025-39
#   Processo já está no formato correto
#   Buscando processo nos parágrafos específicos...
#   Tentando padrão 1: ^Processo\s+n[º°\.]?\s*[:\\s]*([^\n]+)
#   Linha encontrada com padrão 1: Processo n.º 01506.000603/2020-35
#   Texto do processo extraído: º 01506.000603/2020-35
#   Texto do processo limpo: º 01506.000603/2020-35
#   Processo encontrado, iniciando padronização...
#   Processo original para padronização: º 01506.000603/2020-35
#   Processo limpo: 01506.000603/2020-35
#   Processo já está no formato correto
#   Buscando processo nos parágrafos específicos...
#   Tentando padrão 1: ^Processo\s+n[º°\.]?\s*[:\\s]*([^\n]+)
#   Linha encontrada com padrão 1: Processo nº 01410.000368/2024-94
#   Texto do processo extraído: 01410.000368/2024-94
#   Texto do processo limpo: 01410.000368/2024-94
#   Processo encontrado, iniciando padronização...
#   Processo original para padronização: 01410.000368/2024-94
#   Processo limpo: 01410.000368/2024-94
#   Processo já está no formato correto
#   Buscando processo nos parágrafos específicos...
#   Tentando padrão 1: ^Processo\s+n[º°\.]?\s*[:\\s]*([^\n]+)
#   Linha encontrada com padrão 1: Processo n.º 01506.000205/2021-08
#   Texto do processo extraído: º 01506.000205/2021-08
#   Texto do processo limpo: º 01506.000205/2021-08
#   Processo encontrado, iniciando padronização...
#   Processo original para padronização: º 01506.000205/2021-08
#   Processo limpo: 01506.000205/2021-08
#   Processo já está no formato correto
#   Buscando processo nos parágrafos específicos...
#   Tentando padrão 1: ^Processo\s+n[º°\.]?\s*[:\\s]*([^\n]+)
#   Linha encontrada com padrão 1: Processo n.º 01508.000488/2025-93
#   Texto do processo extraído: º 01508.000488/2025-93
#   Texto do processo limpo: º 01508.000488/2025-93
#   Processo encontrado, iniciando padronização...
#   Processo original para padronização: º 01508.000488/2025-93
#   Processo limpo: 01508.000488/2025-93
#   Processo já está no formato correto
#   Buscando processo nos parágrafos específicos...
#   Tentando padrão 1: ^Processo\s+n[º°\.]?\s*[:\\s]*([^\n]+)
#   Linha encontrada com padrão 1: Processo nº: 01508.000533/2025-18
#   Texto do processo extraído: 01508.000533/2025-18
#   Texto do processo limpo: 01508.000533/2025-18
#   Processo encontrado, iniciando padronização...
#   Processo original para padronização: 01508.000533/2025-18
#   Processo limpo: 01508.000533/2025-18
#   Processo já está no formato correto
# === CALCULANDO DATAS DE EXPIRAÇÃO ===
# === CALCULANDO DATA DE EXPIRAÇÃO ===
#   Data publicação: 07/11/2025
#   Prazo: 12 (doze) meses
#   Padrão encontrado: 12 meses
#   Data de expiração calculada: 07/11/2026
#   Linha 0: 07/11/2025 + 12 (doze) meses = 07/11/2026
# === CALCULANDO DATA DE EXPIRAÇÃO ===
#   Data publicação: 07/11/2025
#   Prazo: 24 (vinte e quatro) meses
#   Padrão encontrado: 24 meses
#   Data de expiração calculada: 07/11/2027
#   Linha 1: 07/11/2025 + 24 (vinte e quatro) meses = 07/11/2027
# === CALCULANDO DATA DE EXPIRAÇÃO ===
#   Data publicação: 07/11/2025
#   Prazo: 05 (cinco) meses
#   Padrão encontrado: 5 meses
#   Data de expiração calculada: 07/04/2026
#   Linha 2: 07/11/2025 + 05 (cinco) meses = 07/04/2026
# === CALCULANDO DATA DE EXPIRAÇÃO ===
#   Data publicação: 07/11/2025
#   Prazo: 02 (dois) meses
#   Padrão encontrado: 2 meses
#   Data de expiração calculada: 07/01/2026
#   Linha 3: 07/11/2025 + 02 (dois) meses = 07/01/2026
# === CALCULANDO DATA DE EXPIRAÇÃO ===
#   Data publicação: 07/11/2025
#   Prazo: 08 (oito) meses
#   Padrão encontrado: 8 meses
#   Data de expiração calculada: 07/07/2026
#   Linha 4: 07/11/2025 + 08 (oito) meses = 07/07/2026
# === CALCULANDO DATA DE EXPIRAÇÃO ===
#   Data publicação: 07/11/2025
#   Prazo: 04 (quatro) meses
#   Padrão encontrado: 4 meses
#   Data de expiração calculada: 07/03/2026
#   Linha 5: 07/11/2025 + 04 (quatro) meses = 07/03/2026
# === CALCULANDO DATA DE EXPIRAÇÃO ===
#   Data publicação: 07/11/2025
#   Prazo: 06 (seis) meses
#   Padrão encontrado: 6 meses
#   Data de expiração calculada: 07/05/2026
#   Linha 6: 07/11/2025 + 06 (seis) meses = 07/05/2026
# === CALCULANDO DATA DE EXPIRAÇÃO ===
#   Data publicação: 07/11/2025
#   Prazo: 04 (quatro) meses
#   Padrão encontrado: 4 meses
#   Data de expiração calculada: 07/03/2026
#   Linha 7: 07/11/2025 + 04 (quatro) meses = 07/03/2026
# === CALCULANDO DATA DE EXPIRAÇÃO ===
#   Data publicação: 07/11/2025
#   Prazo: 06 (seis) meses
#   Padrão encontrado: 6 meses
#   Data de expiração calculada: 07/05/2026
#   Linha 8: 07/11/2025 + 06 (seis) meses = 07/05/2026
# === CALCULANDO DATA DE EXPIRAÇÃO ===
#   Data publicação: 07/11/2025
#   Prazo: 03 (três) meses
#   Padrão encontrado: 3 meses
#   Data de expiração calculada: 07/02/2026
#   Linha 9: 07/11/2025 + 03 (três) meses = 07/02/2026
# === CALCULANDO DATA DE EXPIRAÇÃO ===
#   Data publicação: 07/11/2025
#   Prazo: 03 (três) meses
#   Padrão encontrado: 3 meses
#   Data de expiração calculada: 07/02/2026
#   Linha 10: 07/11/2025 + 03 (três) meses = 07/02/2026
# === CALCULANDO DATA DE EXPIRAÇÃO ===
#   Data publicação: 07/11/2025
#   Prazo: 04 (quatro) meses
#   Padrão encontrado: 4 meses
#   Data de expiração calculada: 07/03/2026
#   Linha 11: 07/11/2025 + 04 (quatro) meses = 07/03/2026
# === CALCULANDO DATA DE EXPIRAÇÃO ===
#   Data publicação: 07/11/2025
#   Prazo: 04 (quatro) meses
#   Padrão encontrado: 4 meses
#   Data de expiração calculada: 07/03/2026
#   Linha 12: 07/11/2025 + 04 (quatro) meses = 07/03/2026
# === CALCULANDO DATA DE EXPIRAÇÃO ===
#   Data publicação: 07/11/2025
#   Prazo: 04 (quatro) meses
#   Padrão encontrado: 4 meses
#   Data de expiração calculada: 07/03/2026
#   Linha 13: 07/11/2025 + 04 (quatro) meses = 07/03/2026
# === CALCULANDO DATA DE EXPIRAÇÃO ===
#   Data publicação: 07/11/2025
#   Prazo: 03 (três) meses
#   Padrão encontrado: 3 meses
#   Data de expiração calculada: 07/02/2026
#   Linha 14: 07/11/2025 + 03 (três) meses = 07/02/2026
# === CALCULANDO DATA DE EXPIRAÇÃO ===
#   Data publicação: 07/11/2025
#   Prazo: 04 (quatro) meses
#   Padrão encontrado: 4 meses
#   Data de expiração calculada: 07/03/2026
#   Linha 15: 07/11/2025 + 04 (quatro) meses = 07/03/2026
# === CALCULANDO DATA DE EXPIRAÇÃO ===
#   Data publicação: 07/11/2025
#   Prazo: 04 (quatro) meses
#   Padrão encontrado: 4 meses
#   Data de expiração calculada: 07/03/2026
#   Linha 16: 07/11/2025 + 04 (quatro) meses = 07/03/2026
# === CALCULANDO DATA DE EXPIRAÇÃO ===
#   Data publicação: 07/11/2025
#   Prazo: 04 (quatro) meses
#   Padrão encontrado: 4 meses
#   Data de expiração calculada: 07/03/2026
#   Linha 17: 07/11/2025 + 04 (quatro) meses = 07/03/2026
# === CALCULANDO DATA DE EXPIRAÇÃO ===
#   Data publicação: 07/11/2025
#   Prazo: 04 (quatro) meses
#   Padrão encontrado: 4 meses
#   Data de expiração calculada: 07/03/2026
#   Linha 18: 07/11/2025 + 04 (quatro) meses = 07/03/2026
# === CALCULANDO DATA DE EXPIRAÇÃO ===
#   Data publicação: 07/11/2025
#   Prazo: 02 (dois) meses
#   Padrão encontrado: 2 meses
#   Data de expiração calculada: 07/01/2026
#   Linha 19: 07/11/2025 + 02 (dois) meses = 07/01/2026
# === CALCULANDO DATA DE EXPIRAÇÃO ===
#   Data publicação: 07/11/2025
#   Prazo: 04 (quatro) meses
#   Padrão encontrado: 4 meses
#   Data de expiração calculada: 07/03/2026
#   Linha 20: 07/11/2025 + 04 (quatro) meses = 07/03/2026
# === CALCULANDO DATA DE EXPIRAÇÃO ===
#   Data publicação: 07/11/2025
#   Prazo: 03 (três) meses
#   Padrão encontrado: 3 meses
#   Data de expiração calculada: 07/02/2026
#   Linha 21: 07/11/2025 + 03 (três) meses = 07/02/2026
# === CALCULANDO DATA DE EXPIRAÇÃO ===
#   Data publicação: 07/11/2025
#   Prazo: 04 (quatro) meses
#   Padrão encontrado: 4 meses
#   Data de expiração calculada: 07/03/2026
#   Linha 22: 07/11/2025 + 04 (quatro) meses = 07/03/2026
# === CALCULANDO DATA DE EXPIRAÇÃO ===
#   Data publicação: 07/11/2025
#   Prazo: 04 (quatro) meses
#   Padrão encontrado: 4 meses
#   Data de expiração calculada: 07/03/2026
#   Linha 23: 07/11/2025 + 04 (quatro) meses = 07/03/2026
# === CALCULANDO DATA DE EXPIRAÇÃO ===
#   Data publicação: 07/11/2025
#   Prazo: 03 (três) meses
#   Padrão encontrado: 3 meses
#   Data de expiração calculada: 07/02/2026
#   Linha 24: 07/11/2025 + 03 (três) meses = 07/02/2026
# === CALCULANDO DATA DE EXPIRAÇÃO ===
#   Data publicação: 07/11/2025
#   Prazo: 06 (seis) meses
#   Padrão encontrado: 6 meses
#   Data de expiração calculada: 07/05/2026
#   Linha 25: 07/11/2025 + 06 (seis) meses = 07/05/2026
# === CALCULANDO DATA DE EXPIRAÇÃO ===
#   Data publicação: 07/11/2025
#   Prazo: 04 (quatro) meses
#   Padrão encontrado: 4 meses
#   Data de expiração calculada: 07/03/2026
#   Linha 26: 07/11/2025 + 04 (quatro) meses = 07/03/2026
# === CALCULANDO DATA DE EXPIRAÇÃO ===
#   Data publicação: 07/11/2025
#   Prazo: 04 (quatro) meses
#   Padrão encontrado: 4 meses
#   Data de expiração calculada: 07/03/2026
#   Linha 27: 07/11/2025 + 04 (quatro) meses = 07/03/2026
# === FINALIZANDO SCRAPING DA PORTARIA ===
# Total de itens extraídos: 28
# Primeiros 1 registros:
#   Portaria[0]: Portaria nº 102/2025
#   Portaria[1]: Portaria nº 102/2025
#   Portaria[2]: Portaria nº 102/2025
#   Portaria[3]: Portaria nº 102/2025
#   Portaria[4]: Portaria nº 102/2025
#   Data_Publicacao_DOU[0]: 07/11/2025
#   Data_Publicacao_DOU[1]: 07/11/2025
#   Data_Publicacao_DOU[2]: 07/11/2025
#   Data_Publicacao_DOU[3]: 07/11/2025
#   Data_Publicacao_DOU[4]: 07/11/2025
#   Anexo[0]: I
#   Anexo[1]: II
#   Anexo[2]: II
#   Anexo[3]: II
#   Anexo[4]: III
#   Processo[0]: 01506.002938/2013-69
#   Processo[1]: 01504.000034/2019-12
#   Processo[2]: 01516.000256/2025-36
#   Processo[3]: 01502.001705/2025-01
#   Processo[4]: 01508.000917/2024-41
#   Data_Expiracao[0]: 07/11/2026
#   Data_Expiracao[1]: 07/11/2027
#   Data_Expiracao[2]: 07/04/2026
#   Data_Expiracao[3]: 07/01/2026
#   Data_Expiracao[4]: 07/07/2026
# Colunas extraídas: Portaria, Data_Publicacao_DOU, Anexo, N_Autorizacao, Tipo, Regimento_Normativo, Processo, Retificado, Enquadramento_IN, Empreendedor, Empreendimento, Projeto, Arqueologos_Coordenadores, Arqueologos_Campo, Apoio_Institucional, Municipios_Abrangencias, Estados_Abrangencias, Prazo_Validade, Data_Expiracao, Link_Portaria_DOU, Quantidade_Retificado_DOU, Ultimo_Link_Retificado_DOU, Link_Revogado_DOU, Chave_composta
#
# === INICIANDO SCRAPING DA PORTARIA ===
# URL: https://www.in.gov.br/web/dou/-/portaria-n-104-de-10-de-novembro-de-2025-668357065
# === EXTRAINDO DATA DOU ===
#   Analisando linha: Diário Oficial da União
#   Analisando linha: Diário Oficial da União
#   Analisando linha: Leitura do Jornal
#   Analisando linha: Destaques do Diário Oficial da União
#   Analisando linha: Base de Dados de Publicações do DOU
#   Analisando linha: Verificação de autenticidade
#   Analisando linha: Acesso ao sistema de envio de matérias INCom
#   Analisando linha: Concursos e Seleções
#   Analisando linha: Tutorial do APP DOU
#   Analisando linha: Tutorial INCom
#   Analisando linha: Termo de Uso e Política de Privacidade
#   Analisando linha: Portal da Imprensa Nacional
#   Analisando linha: Caminho de Navegação
#   Analisando linha: Serviços
#   Analisando linha: Diário Oficial da União
#   Analisando linha: Portaria nº 104, de 10 de novembro de 2025
#   Analisando linha: Publicador de Conteúdos e Mídias
#   Analisando linha: Portaria nº 104, de 10 de novembro de 2025
#   Analisando linha: https://www.in.gov.br/web/dou/-/portaria-n-104-de-10-de-novembro-de-2025-668357065
#   Analisando linha: Voltar
#   Analisando linha: Compartilhe:
#   Analisando linha: Facebook
#   Analisando linha: Twitter
#   Analisando linha: Linkedin
#   Analisando linha: WhatsApp
#   Analisando linha: WhatsApp
#   Analisando linha: Instagram
#   Analisando linha: Imagem não disponível
#   Analisando linha: Compartilhar
#   Analisando linha: Ícone
#   Analisando linha: Versão certificada
#   Analisando linha: Ícone
#   Analisando linha: Diário Completo
#   Analisando linha: Ícone
#   Analisando linha: Impressão
#   Analisando linha: Brasão do Brasil
#   Analisando linha: Diário Oficial da União
#   Analisando linha: Publicado em:
#   Analisando linha: 12/11/2025
#   Data encontrada (padrão 3): 12/11/2025
# Data DOU: 12/11/2025
# Portaria: Portaria nº 104/2025
# Número de anexos encontrados: 4
#   Buscando processo nos parágrafos específicos...
#   Tentando padrão 1: ^Processo\s+n[º°\.]?\s*[:\\s]*([^\n]+)
#   Tentando padrão 2: ^PROCESSO\s+N[º°\.]?\s*[:\\s]*([^\n]+)
#   Tentando padrão 3: ^\d{2}-\s*Processo\s+n[º°\.]?\s*[:\\s]*([^\n]+)
#   Tentando padrão 4: ^\d{2}-\s*PROCESSO\s+N[º°\.]?\s*[:\\s]*([^\n]+)
#   Nenhum processo encontrado nos parágrafos específicos
#   Buscando processo nos parágrafos específicos...
#   Tentando padrão 1: ^Processo\s+n[º°\.]?\s*[:\\s]*([^\n]+)
#   Tentando padrão 2: ^PROCESSO\s+N[º°\.]?\s*[:\\s]*([^\n]+)
#   Tentando padrão 3: ^\d{2}-\s*Processo\s+n[º°\.]?\s*[:\\s]*([^\n]+)
#   Linha encontrada com padrão 3: 01- Processo n.º 01510.000325/2021-38
# ...
#   Data de expiração calculada: 14/03/2026
#   Linha 24: 14/11/2025 + 04 (quatro) meses = 14/03/2026
# === CALCULANDO DATA DE EXPIRAÇÃO ===
#   Data publicação: 14/11/2025
#   Prazo: 02 (dois) meses
#   Padrão encontrado: 2 meses
#   Data de expiração calculada: 14/01/2026
#   Linha 25: 14/11/2025 + 02 (dois) meses = 14/01/2026
# === CALCULANDO DATA DE EXPIRAÇÃO ===
#   Data publicação: 14/11/2025
#   Prazo: 11 (onze) meses
#   Padrão encontrado: 11 meses
#   Data de expiração calculada: 14/10/2026
#   Linha 26: 14/11/2025 + 11 (onze) meses = 14/10/2026
# === CALCULANDO DATA DE EXPIRAÇÃO ===
#   Data publicação: 14/11/2025
#   Prazo: 03 (três) meses
#   Padrão encontrado: 3 meses
#   Data de expiração calculada: 14/02/2026
#   Linha 27: 14/11/2025 + 03 (três) meses = 14/02/2026
# === CALCULANDO DATA DE EXPIRAÇÃO ===
#   Data publicação: 14/11/2025
#   Prazo: 3 (três) meses
#   Padrão encontrado: 3 meses
#   Data de expiração calculada: 14/02/2026
#   Linha 28: 14/11/2025 + 3 (três) meses = 14/02/2026
# === CALCULANDO DATA DE EXPIRAÇÃO ===
#   Data publicação: 14/11/2025
#   Prazo: 02 (dois) meses
#   Padrão encontrado: 2 meses
#   Data de expiração calculada: 14/01/2026
#   Linha 29: 14/11/2025 + 02 (dois) meses = 14/01/2026
# === CALCULANDO DATA DE EXPIRAÇÃO ===
#   Data publicação: 14/11/2025
#   Prazo: 03 (três) meses
#   Padrão encontrado: 3 meses
#   Data de expiração calculada: 14/02/2026
#   Linha 30: 14/11/2025 + 03 (três) meses = 14/02/2026
# === CALCULANDO DATA DE EXPIRAÇÃO ===
#   Data publicação: 14/11/2025
#   Prazo: 04 (quatro) meses
#   Padrão encontrado: 4 meses
#   Data de expiração calculada: 14/03/2026
#   Linha 31: 14/11/2025 + 04 (quatro) meses = 14/03/2026
# === CALCULANDO DATA DE EXPIRAÇÃO ===
#   Data publicação: 14/11/2025
#   Prazo: 03 (três) meses
#   Padrão encontrado: 3 meses
#   Data de expiração calculada: 14/02/2026
#   Linha 32: 14/11/2025 + 03 (três) meses = 14/02/2026
# === CALCULANDO DATA DE EXPIRAÇÃO ===
#   Data publicação: 14/11/2025
#   Prazo: 04 (quatro) meses
#   Padrão encontrado: 4 meses
#   Data de expiração calculada: 14/03/2026
#   Linha 33: 14/11/2025 + 04 (quatro) meses = 14/03/2026
# === CALCULANDO DATA DE EXPIRAÇÃO ===
#   Data publicação: 14/11/2025
#   Prazo: 06 (seis) meses
#   Padrão encontrado: 6 meses
#   Data de expiração calculada: 14/05/2026
#   Linha 34: 14/11/2025 + 06 (seis) meses = 14/05/2026
# === CALCULANDO DATA DE EXPIRAÇÃO ===
#   Data publicação: 14/11/2025
#   Prazo: 24 (vinte e quatro) meses
#   Padrão encontrado: 24 meses
#   Data de expiração calculada: 14/11/2027
#   Linha 35: 14/11/2025 + 24 (vinte e quatro) meses = 14/11/2027
# === CALCULANDO DATA DE EXPIRAÇÃO ===
#   Data publicação: 14/11/2025
#   Prazo: 18 (dezoito) meses
#   Padrão encontrado: 18 meses
#   Data de expiração calculada: 14/05/2027
#   Linha 36: 14/11/2025 + 18 (dezoito) meses = 14/05/2027
# === CALCULANDO DATA DE EXPIRAÇÃO ===
#   Data publicação: 14/11/2025
#   Prazo: 24 (vinte e quatro) meses
#   Padrão encontrado: 24 meses
#   Data de expiração calculada: 14/11/2027
#   Linha 37: 14/11/2025 + 24 (vinte e quatro) meses = 14/11/2027
# === CALCULANDO DATA DE EXPIRAÇÃO ===
#   Data publicação: 14/11/2025
#   Prazo: 06 (seis) meses
#   Padrão encontrado: 6 meses
#   Data de expiração calculada: 14/05/2026
#   Linha 38: 14/11/2025 + 06 (seis) meses = 14/05/2026
# === FINALIZANDO SCRAPING DA PORTARIA ===
# Total de itens extraídos: 39
# Primeiros 1 registros:
#   Portaria[0]: Portaria nº 106/2025
#   Portaria[1]: Portaria nº 106/2025
#   Portaria[2]: Portaria nº 106/2025
#   Portaria[3]: Portaria nº 106/2025
#   Portaria[4]: Portaria nº 106/2025
#   Data_Publicacao_DOU[0]: 14/11/2025
#   Data_Publicacao_DOU[1]: 14/11/2025
#   Data_Publicacao_DOU[2]: 14/11/2025
#   Data_Publicacao_DOU[3]: 14/11/2025
#   Data_Publicacao_DOU[4]: 14/11/2025
#   Anexo[0]: I
#   Anexo[1]: II
#   Anexo[2]: III
#   Anexo[3]: III
#   Anexo[4]: III
#   Processo[0]: 01506.001851/2024-27
#   Processo[1]: 01421.000149/2023-03
#   Processo[2]: 01506.005166/2016-60
#   Processo[3]: 01512.000366/2025-38
#   Processo[4]: 01506.000865/2025-12
#   Data_Expiracao[0]: 14/11/2026
#   Data_Expiracao[1]: 14/11/2026
#   Data_Expiracao[2]: 14/03/2026
#   Data_Expiracao[3]: 14/07/2026
#   Data_Expiracao[4]: 14/03/2026
# Colunas extraídas: Portaria, Data_Publicacao_DOU, Anexo, N_Autorizacao, Tipo, Regimento_Normativo, Processo, Retificado, Enquadramento_IN, Empreendedor, Empreendimento, Projeto, Arqueologos_Coordenadores, Arqueologos_Campo, Apoio_Institucional, Municipios_Abrangencias, Estados_Abrangencias, Prazo_Validade, Data_Expiracao, Link_Portaria_DOU, Quantidade_Retificado_DOU, Ultimo_Link_Retificado_DOU, Link_Revogado_DOU, Chave_composta
#
# Dataframe atualizado: df_portarias_acumulado
# Total de registros no dataframe: 97
#
# === PRIMEIROS 5 REGISTROS DO DATAFRAME FINAL ===
# Registro 0:
#   Portaria: Portaria nº 101/2025
#   Data_Publicacao_DOU: 06/11/2025
#   Anexo: I
#   Processo: 01498.000778/2013-60
#   Data_Expiracao: 06/11/2026
#
# Registro 1:
#   Portaria: Portaria nº 101/2025
#   Data_Publicacao_DOU: 06/11/2025
#   Anexo: II
#   Processo: 01516.000269/2020-09
#   Data_Expiracao: 06/11/2027
#
# Registro 2:
#   Portaria: Portaria nº 101/2025
#   Data_Publicacao_DOU: 06/11/2025
#   Anexo: III
#   Processo: 01514.001637/2023-91
#   Data_Expiracao: 06/06/2026
#
# Registro 3:
#   Portaria: Portaria nº 101/2025
#   Data_Publicacao_DOU: 06/11/2025
#   Anexo: IV
#   Processo: 01402.000303/2025-29
#   Data_Expiracao: 06/02/2026
#
# Registro 4:
#   Portaria: Portaria nº 101/2025
#   Data_Publicacao_DOU: 06/11/2025
#   Anexo: IV
#   Processo: 01506.000033/2025-98
#   Data_Expiracao: 06/03/2026
#                 Portaria Data_Publicacao_DOU Anexo N_Autorizacao         Tipo  \
# 0   Portaria nº 101/2025          06/11/2025     I            01    RENOVAÇÃO
# 1   Portaria nº 101/2025          06/11/2025    II            01  AUTORIZAÇÃO
# 2   Portaria nº 101/2025          06/11/2025   III            01    RENOVAÇÃO
# 3   Portaria nº 101/2025          06/11/2025    IV            01  AUTORIZAÇÃO
# 4   Portaria nº 101/2025          06/11/2025    IV            02  AUTORIZAÇÃO
# ..                   ...                 ...   ...           ...          ...
# 92  Portaria nº 106/2025          14/11/2025   III            33  AUTORIZAÇÃO
# 93  Portaria nº 106/2025          14/11/2025   III            34  AUTORIZAÇÃO
# 94  Portaria nº 106/2025          14/11/2025   III            35  AUTORIZAÇÃO
# 95  Portaria nº 106/2025          14/11/2025   III            36  AUTORIZAÇÃO
# 96  Portaria nº 106/2025          14/11/2025   III            37  AUTORIZAÇÃO
#
#                                 Regimento_Normativo              Processo  \
# 0   Portaria Iphan nº 230/02 e Portaria SPHAN 07/88  01498.000778/2013-60
# 1                              Portaria SPHAN 07/88  01516.000269/2020-09
# 2                      Instrução Normativa 001/2015  01514.001637/2023-91
# 3                      Instrução Normativa 001/2015  01402.000303/2025-29
# 4                      Instrução Normativa 001/2015  01506.000033/2025-98
# ..                                              ...                   ...
# 92                     Instrução Normativa 001/2015  01409.000375/2025-14
# 93                     Instrução Normativa 001/2015  01514.001069/2020-85
# 94                     Instrução Normativa 001/2015  01408.000369/2025-69
# 95                     Instrução Normativa 001/2015  01516.000702/2024-21
# 96                     Instrução Normativa 001/2015  01516.001557/2008-86
#
#    Retificado                                   Enquadramento_IN  \
# 0         Não                                                NaN
# 1         Não                                                NaN
# 2         Não                                          Nível III
# 3         Não                                          Nível III
# 4         Não                                          Nível III
# ..        ...                                                ...
# 92        Não  Nível III Empreendedor/Responsável Legal: Priv...
# 93        Não                                          Nível III
# 94        Não                                           Nível II
# 95        Não                                          Nível III
# 96        Não                                                III
#
#                                          Empreendedor  \
# 0                                                 NaN
# 1                                                 NaN
# 2   ATAIÁ DA SERRRA DESENVOLVIMENTO IMOBILIÁRIO LTDA.
# 3                  Macedo Fortes Empreendimentos LTDA
# 4        Arajara Empreendimento imobiliário SPE Ltda.
# ..                                                ...
# 92                                                NaN
# 93         Anglo American Minério de Ferro Brasil S.A
# 94  Departamento de Estradas de Rodagem do Estado ...
# 95                      Mosaic Fertilizantes P&K Ltda
# 96                      Terra Goyana Mineradora Ltda.
#
#                                        Empreendimento  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                   Loteamento Sabará
# 3                       Condomínio Francisca da Silva
# 4                                  Loteamento Arajara
# ..                                                ...
# 92                   Areais Itaputanga 014, 075 e 331
# 93                   EXPANSÃO SUL - SISTEMA MINAS-RIO
# 94  Rodovia PB 204: Entr. PB 200 / Distrito de Cam...
# 95  Complexo Mineroquímico de Catalão (CMC) - Mosa...
# 96                            Terra Goyana Mineradora
#
#                                               Projeto  \
# 0   Resgate, Monitoramento Arqueológico e Educação...
# 1   Escavação do Sítio Arqueológico GO-Ja.02: Nova...
# 2   Programa de Gestão do Patrimônio Arqueológico ...
# 3   Avaliação de Impacto o Patrimônio Arqueológico...
# 4   Avaliação de impacto ao patrimônio arqueológic...
# ..                                                ...
# 92  Projeto de Avaliação de Impacto ao Patrimônio ...
# 93  Programa de Gestão do Patrimônio Arqueológico ...
# 94  Projeto de Acompanhamento Arqueológico das obr...
# 95  Programa de Gestão do Patrimônio Arqueológico ...
# 96  Programa de Gestão - Prospecção Arqueológica I...
#
#                             Arqueologos_Coordenadores  \
# 0                                       Renato Kipnis
# 1   Júlio Cezar Rubin de Rubin e Rosiclér Theodoro...
# 2              Fernanda Elisa Costa Paulino e Resende
# 3               Hebert Rogério do Nascimento Coutinho
# 4   Lilia Benevides Guedes, Adilson Pereira Nascim...
# ..                                                ...
# 92                         Francisco João Lopes Silva
# 93  Alexandre Pinto Coelho de Almeida e Fernando A...
# 94                   Jaionara Rodrigues Dias da Silva
# 95           Kaic Bueno Batista e Rafael Nimai Uarian
# 96                                Rute de Lima Pontim
#
#                                     Arqueologos_Campo  \
# 0                                                 NaN
# 1                                                 NaN
# 2   Ana Carolina Cavenague Napolitano e João Paulo...
# 3                              Natália Gomes de Sousa
# 4                             Jouran de Deus Ferreira
# ..                                                ...
# 92                Romulo Mazzocco Machado Bittencourt
# 93                              Gabriela Longo Moraes
# 94                   Jaionara Rodrigues Dias da Silva
# 95                             Higor Gabriel da Serra
# 96                        Júlio César Alves de Castro
#
#                                   Apoio_Institucional  \
# 0   Museu de Arqueologia e Ciências Naturais - Uni...
# 1   Instituto Goiano de Pré-História e Antropologi...
# 2   Laboratório de Arqueologia e Estudo da Paisage...
# 3   Fundação Cultural Cristo Rei - Museu Dom Avela...
# 4    Museu Histórico e Pedagógico João Teodoro Xavier
# ..                                                ...
# 92  Instituto de Pesquisa Arqueológica e Etnográfi...
# 93  Laboratório de Arqueologia e Estudo da Paisage...
# 94                                                NaN
# 95  Museu Histórico Municipal de Jaraguá - Prefeit...
# 96  Núcleo de Arqueologia da Universidade Estadual...
#
#                               Municipios_Abrangencias Estados_Abrangencias  \
# 0   Jaboatão dos Guararapes, Escada, Ipojuca, More...           Pernambuco
# 1                                        Serranópolis                Goiás
# 2                                                 NaN                  NaN
# 3                                            Teresina                Piauí
# 4                                           Ubirajara            São Paulo
# ..                                                ...                  ...
# 92                                              Piúma       Espírito Santo
# 93                           Conceição do Mato Dentro         Minas Gerais
# 94                                Caraúbas e Coxixola              Paraíba
# 95                                            Ouvidor                Goiás
# 96            Barro Alto e Santa Rita do Novo Destino                Goiás
#
#                Prazo_Validade Data_Expiracao  \
# 0             12 (doze) meses     06/11/2026
# 1   24 (vinte e quatro) meses     06/11/2027
# 2             07 (sete) meses     06/06/2026
# 3             03 (três) meses     06/02/2026
# 4           04 (quatro) meses     06/03/2026
# ..                        ...            ...
# 92            06 (seis) meses     14/05/2026
# 93  24 (vinte e quatro) meses     14/11/2027
# 94         18 (dezoito) meses     14/05/2027
# 95  24 (vinte e quatro) meses     14/11/2027
# 96            06 (seis) meses     14/05/2026
#
#                                     Link_Portaria_DOU  \
# 0   https://www.in.gov.br/web/dou/-/portaria-n-101...
# 1   https://www.in.gov.br/web/dou/-/portaria-n-101...
# 2   https://www.in.gov.br/web/dou/-/portaria-n-101...
# 3   https://www.in.gov.br/web/dou/-/portaria-n-101...
# 4   https://www.in.gov.br/web/dou/-/portaria-n-101...
# ..                                                ...
# 92  https://www.in.gov.br/web/dou/-/portaria-n-106...
# 93  https://www.in.gov.br/web/dou/-/portaria-n-106...
# 94  https://www.in.gov.br/web/dou/-/portaria-n-106...
# 95  https://www.in.gov.br/web/dou/-/portaria-n-106...
# 96  https://www.in.gov.br/web/dou/-/portaria-n-106...
#
#     Quantidade_Retificado_DOU  Ultimo_Link_Retificado_DOU  Link_Revogado_DOU  \
# 0                         NaN                         NaN                NaN
# 1                         NaN                         NaN                NaN
# 2                         NaN                         NaN                NaN
# 3                         NaN                         NaN                NaN
# 4                         NaN                         NaN                NaN
# ..                        ...                         ...                ...
# 92                        NaN                         NaN                NaN
# 93                        NaN                         NaN                NaN
# 94                        NaN                         NaN                NaN
# 95                        NaN                         NaN                NaN
# 96                        NaN                         NaN                NaN
#
#                                Chave_composta
# 0   Portaria nº 101/2025_01498.000778/2013-60
# 1   Portaria nº 101/2025_01516.000269/2020-09
# 2   Portaria nº 101/2025_01514.001637/2023-91
# 3   Portaria nº 101/2025_01402.000303/2025-29
# 4   Portaria nº 101/2025_01506.000033/2025-98
# ..                                        ...
# 92  Portaria nº 106/2025_01409.000375/2025-14
# 93  Portaria nº 106/2025_01514.001069/2020-85
# 94  Portaria nº 106/2025_01408.000369/2025-69
# 95  Portaria nº 106/2025_01516.000702/2024-21
# 96  Portaria nº 106/2025_01516.001557/2008-86
#
# [97 rows x 24 columns]

# %% [markdown]
# # Fluxo de Migração dos Dados para o Supabase
#
# ## Funcionalidades Principais
# - ✅ **Configuração automática** do ambiente de trabalho
# - 🔐 **Conexão segura** com banco de dados Supabase
# - 📊 **Processamento inteligente** de dados
# - 🔄 **Atualização automática** de registros existentes
# - 📋 **Relatórios detalhados** do processo
# - 🛡️ **Verificações de segurança** em todas as etapas
#
# ## Fluxo Simplificado
# 1. Configura ambiente automaticamente
# 2. Conecta ao banco de dados online
# 3. Processa e padroniza os dados
# 4. Envia informações com controle de qualidade
# 5. Gera relatório final de execução

# %%
# Carregando bibliotecas

import os
import requests
import pandas as pd
import json
from dotenv import load_dotenv, set_key, find_dotenv
from IPython.display import display

# %%
def create_env_file():
    """Criar arquivo .env automaticamente com codificação UTF-8"""
    env_content = '''# CONFIGURAÇÕES DO SUPABASE
SUPABASE_URL=https://wacqxihunefahztqpaet.supabase.co
SUPABASE_KEY=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6IndhY3F4aWh1bmVmYWh6dHFwYWV0Iiwicm9sZSI6ImFub24iLCJpYXQiOjE3NjMzMzEwNjYsImV4cCI6MjA3ODkwNzA2Nn0.4Xop4iqipp7UKPLOdlvTkd4FeJTi4Y1UF48E0l8K0Ng
SUPABASE_DB_PASSWORD=Iphaner@2025Ag%+mqU&
*-et
# CONFIGURAÇÕES OPCIONAIS
PROJECT_NAME=Extracao de Portarias Autorizativas no DOU
ENVIRONMENT=development'''
    
    # Salvar com codificação UTF-8
    with open('.env', 'w', encoding='utf-8') as f:
        f.write(env_content)
    
    print("✅ Arquivo .env criado com sucesso!")
    print("📁 Local: ", os.getcwd() + "/.env")

# %%
def check_env_config():
    """Função para verificar configuração com tratamento de codificação"""
    # Verificar se arquivo existe
    if not os.path.exists('.env'):
        print("❌ Arquivo .env NÃO encontrado!")
        print("📁 Diretório atual:", os.getcwd())
        print("💡 Execute create_env_file() para criar o arquivo")
        return False
    
    # Carregar variáveis com tratamento de erro de codificação
    try:
        # Tentar carregar com UTF-8 primeiro
        load_dotenv('.env', encoding='utf-8')
    except UnicodeDecodeError:
        try:
            # Se UTF-8 falhar, tentar latin-1
            print("⚠️  Tentando carregar com codificação latin-1...")
            load_dotenv('.env', encoding='latin-1')
        except Exception as e:
            print(f"❌ Erro ao carregar arquivo .env: {e}")
            return False
    except Exception as e:
        print(f"❌ Erro inesperado: {e}")
        return False
    
    # Verificar variáveis obrigatórias
    required_vars = ['SUPABASE_URL', 'SUPABASE_KEY']
    missing_vars = []
    
    for var in required_vars:
        value = os.getenv(var)
        if not value:
            missing_vars.append(var)
    
    if missing_vars:
        print("❌ Variáveis faltando no .env:")
        for var in missing_vars:
            print(f" - {var}")
        return False
    
    # Mostrar configuração (ocultando dados sensíveis)
    url = os.getenv('SUPABASE_URL')
    key = os.getenv('SUPABASE_KEY')
    key_preview = f"{key[:20]}..." if key else ""
    
    print("✅ Configuração .env carregada com sucesso!")
    print(f"🌐 URL: {url}")
    print(f"🔑 Key: {key_preview}")
    print(f"📊 DB Password: {'Configurado' if os.getenv('SUPABASE_DB_PASSWORD') else 'Não configurado'}")
    
    return True

# %%
def load_env_safe():
    """Carregar variáveis de ambiente com fallback seguro"""
    if not os.path.exists('.env'):
        print("❌ Arquivo .env não encontrado. Criando...")
        create_env_file()
    
    # Tentar diferentes codificações
    encodings = ['utf-8', 'latin-1', 'cp1252', 'iso-8859-1']
    
    for encoding in encodings:
        try:
            load_dotenv('.env', encoding=encoding)
            print(f"✅ Arquivo .env carregado com codificação: {encoding}")
            return True
        except UnicodeDecodeError:
            continue
        except Exception as e:
            print(f"❌ Erro com codificação {encoding}: {e}")
            continue
    
    print("❌ Não foi possível carregar o arquivo .env com nenhuma codificação suportada")
    return False

# %%
def connect_supabase_rest():
    """Função para conectar via REST API"""
    # Garantir que as variáveis estão carregadas
    if not load_env_safe():
        raise Exception("Não foi possível carregar as variáveis de ambiente")
    
    supabase_url = os.getenv('SUPABASE_URL')
    supabase_key = os.getenv('SUPABASE_KEY')
    
    if not supabase_url or not supabase_key:
        raise Exception("Configure as variáveis SUPABASE_URL e SUPABASE_KEY no arquivo .env")
    
    return {'url': supabase_url, 'key': supabase_key}

# %%
def upload_to_supabase(df, table_name="portarias_iphan"):
    """Função para enviar dados via REST API"""
    config = connect_supabase_rest()
    
    # Converter dataframe para JSON
    data_json = df.to_json(orient='records', date_format='iso')
    
    # Fazer requisição para inserir dados
    headers = {
        "apikey": config['key'],
        "Authorization": f"Bearer {config['key']}",
        "Content-Type": "application/json",
        "Prefer": "resolution=merge-duplicates"
    }
    
    try:
        response = requests.post(
            url=f"{config['url']}/rest/v1/{table_name}",
            headers=headers,
            data=data_json
        )
        
        if 200 <= response.status_code < 300:
            print("✅ Dados enviados com sucesso para o Supabase!")
            print(f"📊 Registros enviados: {len(df)}")
        else:
            print("❌ Erro ao enviar dados:")
            print(f"Código: {response.status_code}")
            print(f"Mensagem: {response.text}")
        
        return response
        
    except Exception as e:
        print(f"❌ Erro na requisição: {e}")
        return None

# %%
def upsert_to_supabase(df, table_name="portarias_iphan"):
    """Função para UPSERT (inserir ou atualizar) dados"""
    config = connect_supabase_rest()
    
    success_count = 0
    error_count = 0
    
    for i in range(len(df)):
        row_data = df.iloc[[i]]
        data_json = row_data.to_json(orient='records', date_format='iso')
        
        headers = {
            "apikey": config['key'],
            "Authorization": f"Bearer {config['key']}",
            "Content-Type": "application/json",
            "Prefer": "resolution=merge-duplicates"
        }
        
        try:
            response = requests.post(
                url=f"{config['url']}/rest/v1/{table_name}",
                headers=headers,
                data=data_json
            )
            
            if 200 <= response.status_code < 300:
                success_count += 1
            else:
                error_count += 1
                print(f"Erro na linha {i}: {response.text}")
                
        except Exception as e:
            error_count += 1
            print(f"Erro na linha {i}: {e}")
    
    print("📊 Resultado do upload:")
    print(f"✅ Sucessos: {success_count}")
    print(f"❌ Erros: {error_count}")
    
    return {'success': success_count, 'error': error_count}

# %%
def verify_supabase_data(table_name="portarias_iphan"):
    """Verificar dados no Supabase"""
    config = connect_supabase_rest()
    
    headers = {
        "apikey": config['key'],
        "Authorization": f"Bearer {config['key']}"
    }
    
    try:
        response = requests.get(
            url=f"{config['url']}/rest/v1/{table_name}?select=count",
            headers=headers
        )
        
        if response.status_code == 200:
            count_data = response.json()
            print(f"📊 Total de registros na tabela Supabase: {count_data[0]['count']}")
        else:
            print(f"❌ Erro ao verificar dados: {response.status_code}")
            
    except Exception as e:
        print(f"❌ Erro na requisição: {e}")

# %%
def check_table_structure(table_name="portarias_iphan"):
    """Função para verificar estrutura da tabela"""
    config = connect_supabase_rest()
    
    headers = {
        "apikey": config['key'],
        "Authorization": f"Bearer {config['key']}"
    }
    
    try:
        response = requests.get(
            url=f"{config['url']}/rest/v1/{table_name}?limit=1",
            headers=headers
        )
        
        if response.status_code == 200:
            data = response.json()
            if data:
                print("✅ Colunas existentes na tabela:")
                for col in data[0].keys():
                    print(f" - {col}")
            else:
                print("ℹ️ Tabela existe mas está vazia")
        else:
            print(f"❌ Erro ao acessar tabela: {response.status_code}")
            
    except Exception as e:
        print(f"❌ Erro na requisição: {e}")

# %%
# FLUXO PRINCIPAL - EXECUÇÃO NO JUPYTER NOTEBOOK

print("🔧 INICIANDO CONFIGURAÇÃO DO SUPABASE")
print("=" * 50)

# 1. Criar arquivo .env se não existir
if not os.path.exists('.env'):
    print("📝 Criando arquivo .env...")
    create_env_file()
else:
    print("✅ Arquivo .env já existe")

# 2. Verificar configuração
print("\n🔍 VERIFICANDO CONFIGURAÇÃO")
print("-" * 30)
config_ok = check_env_config()

if not config_ok:
    print("\n❌ CONFIGURAÇÃO FALHOU - Verifique o arquivo .env")
else:
    print("\n✅ CONFIGURAÇÃO BEM-SUCEDIDA")
    
    # 3. Testar conexão com Supabase
    print("\n🌐 TESTANDO CONEXÃO COM SUPABASE")
    print("-" * 30)
    try:
        config = connect_supabase_rest()
        print("✅ Conexão com Supabase configurada com sucesso!")
        print(f"🌐 URL: {config['url']}")
        print(f"🔑 Key: {config['key'][:20]}...")
    except Exception as e:
        print(f"❌ Erro na conexão: {e}")

print("\n🚀 CONFIGURAÇÃO CONCLUÍDA - Pronto para uso!")
# Out:
# 🔧 INICIANDO CONFIGURAÇÃO DO SUPABASE
# ==================================================
# ✅ Arquivo .env já existe
#
# 🔍 VERIFICANDO CONFIGURAÇÃO
# ------------------------------
# ⚠️  Tentando carregar com codificação latin-1...
# ✅ Configuração .env carregada com sucesso!
# 🌐 URL: https://wacqxihunefahztqpaet.supabase.co
# 🔑 Key: eyJhbGciOiJIUzI1NiIs...
# 📊 DB Password: Configurado
#
# ✅ CONFIGURAÇÃO BEM-SUCEDIDA
#
# 🌐 TESTANDO CONEXÃO COM SUPABASE
# ------------------------------
# ✅ Arquivo .env carregado com codificação: latin-1
# ✅ Conexão com Supabase configurada com sucesso!
# 🌐 URL: https://wacqxihunefahztqpaet.supabase.co
# 🔑 Key: eyJhbGciOiJIUzI1NiIs...
#
# 🚀 CONFIGURAÇÃO CONCLUÍDA - Pronto para uso!

# %%
# Converter colunas para minúsculas
df_resultado.columns = df_resultado.columns.str.lower()

# %%
# Verificar dados
print("📋 Resumo dos dados:")
print(f"Número de registros: {len(df_resultado)}")
print(f"Colunas: {', '.join(df_resultado.columns)}")
# Out:
# 📋 Resumo dos dados:
# Número de registros: 97
# Colunas: portaria, data_publicacao_dou, anexo, n_autorizacao, tipo, regimento_normativo, processo, retificado, enquadramento_in, empreendedor, empreendimento, projeto, arqueologos_coordenadores, arqueologos_campo, apoio_institucional, municipios_abrangencias, estados_abrangencias, prazo_validade, data_expiracao, link_portaria_dou, quantidade_retificado_dou, ultimo_link_retificado_dou, link_revogado_dou, chave_composta

# %%
# Verificar chaves únicas na coluna chave_composta
if 'chave_composta' in df_resultado.columns:
    chaves_unicas = df_resultado['chave_composta'].unique()
    print(f"Chaves únicas encontradas: {len(chaves_unicas)}")
# Out:
# Chaves únicas encontradas: 97

# %%
# Enviar para o Supabase
print("☁️ Enviando dados para o Supabase...")
resultado = upsert_to_supabase(df_resultado)
# Out:
# ☁️ Enviando dados para o Supabase...
# ✅ Arquivo .env carregado com codificação: latin-1
# 📊 Resultado do upload:
# ✅ Sucessos: 97
# ❌ Erros: 0

# %%
# Verificar dados
verify_supabase_data()
check_table_structure()
# Out:
# ✅ Arquivo .env carregado com codificação: latin-1
# 📊 Total de registros na tabela Supabase: 97
# ✅ Arquivo .env carregado com codificação: latin-1
# ✅ Colunas existentes na tabela:
#  - id
#  - portaria
#  - data_publicacao_dou
#  - anexo
#  - n_autorizacao
#  - tipo
#  - regimento_normativo
#  - processo
#  - retificado
#  - enquadramento_in
#  - empreendedor
#  - empreendimento
#  - projeto
#  - arqueologos_coordenadores
#  - arqueologos_campo
#  - apoio_institucional
#  - municipios_abrangencias
#  - estados_abrangencias
#  - prazo_validade
#  - data_expiracao
#  - link_portaria_dou
#  - quantidade_retificado_dou
#  - ultimo_link_retificado_dou
#  - link_revogado_dou
#  - chave_composta
#  - created_at
#  - updated_at

# %% [markdown]
# # Fim
